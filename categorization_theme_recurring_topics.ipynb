# %% [markdown]
# # Documentation

# %% [markdown]
# ## Overview
# This script processes article data using OpenAI's GPT model to categorize articles, identify niches, extract key themes, and recurring topics. The results are saved in a Parquet file format.
#
# ## Key Functionalities
# 1. **Data Loading:**
#    - Merges data from two Parquet files.
# 2. **Category and Niche Extraction:**
#    - Uses LLM to categorize articles and identify niches based on titles and content.
# 3. **Key Themes and Recurring Topics:**
#    - Extracts broad themes and specific topics from text excerpts.
# 4. **Error Handling:**
#    - Implements retry logic for API calls and checkpoint saving.
#
# ## Dependencies
# - pandas
# - openai
# - tqdm
# - json
# - re
# - os
#
# ## Code Walkthrough
# ### 1. Data Loading
# - Loads and merges Parquet files into a DataFrame.
# - Displays the count of loaded rows.
#
# ### 2. Category and Niche Extraction
# - `process_title`: Sends article titles to LLM for category and niche extraction.
# - `process_text_chunks`: Processes content in chunks if the title is insufficient.
#
# ### 3. Key Themes and Recurring Topics
# - `extract_key_themes_and_recurring_topics`: Extracts themes from the introduction and recurring topics from the entire text.
#
# ### 4. Error Handling
# - Implements retries for API rate limits.
# - Saves checkpoints periodically.
#
# ### 5. Saving Results
# - Saves processed results into a Parquet file.
#
# ## Usage
# Run the script with a valid OpenAI API key set in the environment variables:
# ```
# export OPENAI_API_KEY="your_api_key"
# python script.py
# ```
#
# ## Conclusion
# This script automates the categorization of articles and extraction of insights using OpenAI's API, providing a structured approach to handling large datasets.

# %% [markdown]
# # Code

# %%
import os
import pandas as pd
import json
import re
from tqdm import tqdm
import openai
import time

openai.api_key = os.getenv("OPENAI_API_KEY")

print("Loading data...")
df1 = pd.read_parquet("kpmg_india/kpmg_final_concatenated_insights_gzip.parquet")
df2 = pd.read_parquet("pwc_india/pwc_final_concatenated_insights_gzip.parquet")
df = pd.concat([df1, df2], ignore_index=True)
print(f"Loaded {len(df)} rows after merging")

def save_checkpoint(df, iteration, total):
    checkpoint_file = f"checkpoint_{iteration}_of_{total}.parquet"
    df.to_parquet(checkpoint_file, compression="gzip")
    print(f"Checkpoint saved: {checkpoint_file}")

def extract_json(text):
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        json_pattern = r'({[\s\S]*})'
        json_match = re.search(json_pattern, text)
        if json_match:
            try:
                return json.loads(json_match.group(1))
            except json.JSONDecodeError:
                pass
        category_match = re.search(r'category[:\s]+["\'](.*?)["\']', text, re.IGNORECASE)
        niche_match = re.search(r'niche[:\s]+["\'](.*?)["\']', text, re.IGNORECASE)
        if category_match and niche_match:
            return {"category": category_match.group(1), "niche": niche_match.group(1)}
        return {"category": "", "niche": ""}

def extract_list_from_response(text):
    try:
        data = json.loads(text)
        if isinstance(data, dict) and "items" in data:
            return data["items"]
        elif isinstance(data, list):
            return data
        
        matches = re.findall(r'[\"\']([^\"\']+)[\"\']', text)
        if matches:
            return matches
            
        list_items = re.findall(r'(?:^|\n)[\d\-\*]+\.?\s*([^\n]+)', text)
        if list_items:
            return [item.strip() for item in list_items]
            
    except json.JSONDecodeError:
        pass
    
    if "," in text:
        return [item.strip() for item in text.split(",") if item.strip()]
    else:
        return [item.strip() for item in text.split("\n") if item.strip()]

def invoke_llm(prompt, max_retries=5):
    for attempt in range(max_retries):
        try:
            response = openai.ChatCompletion.create(
                model="gpt-4o-mini",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.0
            )
            return response.choices[0].message['content'].strip()
        except Exception as e:
            if "429" in str(e):
                wait_time = 2 ** attempt
                print(f"Rate limit exceeded. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                print(f"LLM request failed: {e}")
                break
    return ""

def process_title(title):
    prompt = f"""
    Given the following article title:
    "{title}"

    Classify it into one of these categories:
    ["Supply Chain", "Energy Renewables", "Cyber Security", "Economy and Growth", "ESG", "Technology", "Risk Regulation", "Workforce", "Transformation", "India (Country)", "Healthcare"]

    Additionally, identify a relevant **niche** within this category.
    The **category must be from the list**, but the **niche can be any relevant term**.

    Return ONLY a JSON object with 2 keys: "category" and "niche".
    Example: {{"category": "Technology", "niche": "Cloud Computing"}}
    
    Do not include ANY explanatory text before or after the JSON.
    """
    response = invoke_llm(prompt)
    return extract_json(response)

def process_text_chunks(text):
    chunk_size = 400
    words = text.split()
    num_chunks = min(2, len(words) // chunk_size + (1 if len(words) % chunk_size > 0 else 0))

    category_votes = []
    niche_votes = []

    for i in range(num_chunks):
        chunk = " ".join(words[i * chunk_size:(i + 1) * chunk_size])
        prompt = f"""
        Given the following article excerpt:
        "{chunk}"

        Classify it into one of these categories:
        ["Supply Chain", "Energy Renewables", "Cyber Security", "Economy and Growth", "ESG", "Technology", "Risk Regulation", "Workforce", "Transformation", "India (Country)", "Healthcare"]

        Additionally, identify a relevant **niche** within this category.
        The **category must be from the list**, but the **niche can be any relevant term**.

        Return ONLY a JSON object with 2 keys: "category" and "niche".
        Example: {{"category": "Technology", "niche": "Cloud Computing"}}
        
        Do not include ANY explanatory text before or after the JSON.
        """
        response = invoke_llm(prompt)
        result = extract_json(response)
        category_votes.append(result.get("category", ""))
        niche_votes.append(result.get("niche", ""))

    final_category = max(set(category_votes), key=category_votes.count) if category_votes else ""
    final_niche = max(set(niche_votes), key=niche_votes.count) if niche_votes else ""

    return {"category": final_category, "niche": final_niche}

def extract_key_themes_recurring_topics_summaries(text):
    """
    Extracts key themes from the introduction (first 1/3rd of the text) and 
    recurring topics from the remaining text, processing the text in chunks.
    
    Additionally, extracts summaries for each chunk and concatenates them into a final summary.
    
    Returns:
        tuple: (list of key themes, list of recurring topics, concatenated summary)
    """
    if pd.isna(text) or text == "":
        return [], [], ""
    
    total_length = len(text)
    intro_threshold = total_length // 3
    chunk_size = 3000
    key_themes = []
    recurring_topics = []
    summaries = []

    for i in range(0, intro_threshold, chunk_size):
        chunk = text[i:i + chunk_size]
        prompt_intro = f'''
        Given the following text excerpt from an article:
        "{chunk}"
        
        Instructions:
        Identify the most important key themes addressed in this text.
        Key themes should be broad concepts or subjects that form the foundation of the content.
        
        Additionally, identify specific recurring topics that are mentioned or discussed multiple times in this excerpt.
        Recurring topics should be specific subjects, terms, or concepts that appear repeatedly.
        
        Finally, provide a concise summary of the text excerpt.
        Just give me the summary do not give an introduction like This excerpt discusses or This text summarizes t.
        
        Return ONLY a JSON object with three keys: "key_themes", "recurring_topics", and "summary".
        Example: {{"key_themes": ["Digital Transformation", "Regulatory Compliance"], 
                  "recurring_topics": ["Supply Chain Disruption", "Blockchain Implementation"], 
                  "summary": "Digital transformation and regulatory compliance are central themes, with discussions on supply chain disruptions and blockchain implementation."}}
        
        Be concise and specific. Each summary should be under 300 words, and should include any of the metrics that are mentioned.
        Do not include ANY explanatory text before or after the JSON.
        '''
        response_intro = invoke_llm(prompt_intro)
        result = extract_json(response_intro) or {}
        
        if "key_themes" in result:
            new_key_themes = result.get("key_themes", [])
            for theme in new_key_themes:
                cleaned_theme = theme.strip()
                if cleaned_theme and cleaned_theme.lower() not in [t.lower() for t in key_themes]:
                    key_themes.append(cleaned_theme)
        else:
            new_key_themes = extract_list_from_response(response_intro)
            for theme in new_key_themes:
                cleaned_theme = theme.strip()
                if cleaned_theme and cleaned_theme.lower() not in [t.lower() for t in key_themes]:
                    key_themes.append(cleaned_theme)
        
        if "recurring_topics" in result:
            new_topics = result.get("recurring_topics", [])
            recurring_topics.extend(new_topics)
        
        summary = result.get("summary", "").strip()
        if summary:
            summaries.append(summary)

    for j in range(intro_threshold, total_length, chunk_size):
        chunk = text[j:j + chunk_size]
        prompt_remaining = f'''
        Given the following text excerpt from an article:
        "{chunk}"
        
        Instructions:
        Identify the recurring topics that are mentioned or discussed multiple times.
        Recurring topics should be specific subjects, terms, or concepts that appear repeatedly.
        
        Additionally, provide a concise summary of the text excerpt.
        Just give me the summary do not give an introduction like This excerpt discusses or This text summarizes t.
        
        Return ONLY a JSON object with two keys: "items" and "summary".
        Example: {{"items": ["Supply Chain Disruption", "Blockchain Implementation"], 
                  "summary": "Digital transformation and regulatory compliance are central themes, with discussions on supply chain disruptions and blockchain implementation."}}
        
        Be specific and detailed. Each summary should be under 300 words, and should include any of the metrics that are mentioned.
        Do not include ANY explanatory text before or after the JSON.
        '''
        response_remaining = invoke_llm(prompt_remaining)
        result = extract_json(response_remaining)
        
        if "items" in result:
            remaining_topics = result.get("items", [])
            recurring_topics.extend(remaining_topics)
        else:
            remaining_topics = extract_list_from_response(response_remaining)
            recurring_topics.extend(remaining_topics)
        
        summary = result.get("summary", "").strip()
        if summary:
            summaries.append(summary)

    unique_recurring_topics = []
    lower_topics = set()
    for topic in recurring_topics:
        cleaned_topic = topic.strip()
        if cleaned_topic and cleaned_topic.lower() not in lower_topics:
            unique_recurring_topics.append(cleaned_topic)
            lower_topics.add(cleaned_topic.lower())
    
    final_summary = "\n".join(summaries) if summaries else ""
    
    return key_themes, unique_recurring_topics, final_summary

def main():
    if "category" not in df.columns:
        df["category"] = None
    if "niche" not in df.columns:
        df["niche"] = None
    if "key_themes" not in df.columns:
        df["key_themes"] = None
    if "recurring_topics" not in df.columns:
        df["recurring_topics"] = None
    if "summary" not in df.columns:
        df["summary"] = None

    total_rows = len(df)
    checkpoint_interval = 50

    try:
        for i in tqdm(range(total_rows)):
            title = df.at[i, "title"]
            text = df.at[i, "normalized_concatenated_text"] if "normalized_concatenated_text" in df.columns else ""

            if (pd.notna(df.at[i, "category"]) and 
                pd.notna(df.at[i, "niche"]) and 
                pd.notna(df.at[i, "key_themes"]) and 
                pd.notna(df.at[i, "recurring_topics"]) and 
                pd.notna(df.at[i, "summary"])):
                continue

            if pd.isna(title) or title == "":
                df.at[i, "category"] = ""
                df.at[i, "niche"] = ""
                df.at[i, "key_themes"] = []
                df.at[i, "recurring_topics"] = []
                df.at[i, "summary"] = ""
                continue

            if pd.isna(df.at[i, "category"]) or pd.isna(df.at[i, "niche"]):
                title_result = process_title(title)
                text_result = process_text_chunks(text) if text else {"category": "", "niche": ""}
                final_category = title_result["category"] if title_result["category"] else text_result["category"]
                final_niche = title_result["niche"] if title_result["niche"] else text_result["niche"]
                df.at[i, "category"] = final_category
                df.at[i, "niche"] = final_niche
                print(f"Row {i}: {title} → Category: {final_category}, Niche: {final_niche}")

            if pd.isna(df.at[i, "key_themes"]) or pd.isna(df.at[i, "recurring_topics"]) or pd.isna(df.at[i, "summary"]):
                key_themes, recurring_topics, final_summary = extract_key_themes_recurring_topics_summaries(text)
                df.at[i, "key_themes"] = key_themes
                df.at[i, "recurring_topics"] = recurring_topics
                df.at[i, "summary"] = final_summary
                print(f"Row {i}: Key Themes: {key_themes}")
                print(f"Row {i}: Recurring Topics: {recurring_topics}")
                print(f"Row {i}: Final Summary: {final_summary}")

            if (i + 1) % checkpoint_interval == 0:
                save_checkpoint(df, i + 1, total_rows)

        df['date'] = pd.to_datetime(df['date'], errors='coerce', infer_datetime_format=True).dt.strftime('%m/%d/%y')
        df.to_parquet("final_categorized_with_themes_and_summaries.parquet", compression="gzip")
        print("Processing complete. Final results saved.")
    
    except Exception as e:
        print(f"Error during processing: {e}")
        save_checkpoint(df, "error", total_rows)
        print("Progress saved before error.")
        raise e

if __name__ == "__main__":
    main()
# Out:
# Loading data...
# Loaded 17 rows after merging
#   0%|          | 0/17 [00:00<?, ?it/s]
# Row 0: Issue no. 103 | February 2025 → Category: Economy and Growth, Niche: Inflation Trends
#   6%|▌         | 1/17 [01:29<23:49, 89.37s/it]
# Row 0: Key Themes: ['Business Combinations', 'Sustainability Disclosure', 'Regulatory Compliance', 'Business Combination Accounting', 'Measurement Period', 'Business Combination', 'Provisional Amount', 'Financial Reporting', 'Accounting Business Combinations', 'Measurement Period Adjustments', 'Fair Value Assessment', 'Depreciation and Goodwill', 'Sustainability Reporting', 'Material Information Disclosure', 'Financial Statement Adjustments', 'Sustainability-related Financial Disclosure', 'Materiality Judgement', 'General Purpose Financial Reporting', 'User Decision-Making']
# Row 0: Recurring Topics: ['IFRS', 'Measurement Period', 'Acquisition Method', 'Material Information', 'Sustainability-related Risks and Opportunities', 'Sustainability-related risk and opportunity', 'Material information disclosure', 'Regulatory updates from SEBI', 'Audit committee review', 'Measurement period in business combinations', 'Acquisition Date', 'Adjustment', 'Goodwill', 'Identifiable Assets', 'Liabilities', 'Noncontrolling Interest', 'Provisional Amount', 'Asset Valuation', 'Independent Valuation', 'Financial Statements', 'INR 983 crore acquisition', 'provisional fair value', 'depreciation expense', 'goodwill adjustment', 'IFRS Sustainability Disclosure Standards', 'Entity Prospects', 'Primary User', 'Disclosure Requirements', 'Materiality Judgement', 'Primary User Decision Making', 'General Purpose Financial Report', 'Sustainability-Related Financial Disclosure', 'Information Needs of Primary Users', 'Assessment of Material Information', 'sustainability-related risk', 'IFRS standards', 'education material', 'Quantitative Factors', 'Qualitative Factors', 'Cash Flow', 'Resource Consumption', 'Return on Investment', 'Market Share', 'GHG Emissions', 'Entity-specific External Qualitative Factors', 'Geographical Location', 'Industry Sector', 'Economic State', 'judgment', 'aggregate and disaggregate information', 'materiality judgment', 'change in circumstance', 'materiality', 'information aggregation and disaggregation', 'regulatory compliance', 'secretarial compliance report', 'auditor appointment', 'related party transactions', 'public feedback', 'SEBI listing obligations', 'Secretarial Audit', 'Statutory Auditor', 'Audit Committee Approval', 'Related Party Transactions (RPT)', 'Monetary Thresholds', 'Subsidiary Financial Track Record', 'SEBI', 'Industry Standard Recognition Manual', 'Related Party Transactions (RPTs)', 'Audit Committee', 'Material RPTs', 'KPMG Assurance Consulting', 'Implementation Standards', 'Regulated Entities', 'Environmental Social Governance (ESG)', 'ESG Rating', 'Financial Statement Audits', 'Compliance Deadlines', 'Dematerialisation of Securities', 'Quality Control', 'Audit Reports', 'Noncompliance', 'Settlement Procedures', 'Asset Reconstruction Companies (ARCs)', 'Reserve Bank of India (RBI) Guidelines', 'Non-Performing Assets (NPAs)', 'Private Placement Nonconvertible Debentures (NCDs)', 'Nonbanking Financial Companies (NBFCs)', 'Housing Finance Companies (HFCs)', 'Regulatory Sandbox', 'Insurance Regulatory Development Authority of India (IRDAI)', 'Data Governance', 'Operational Efficiency', 'Artificial Intelligence (AI)', 'Machine Learning (ML)', 'AI/ML Tools Regulation', 'SEBI Guidelines', 'AIF Regulation', 'Water Pollution Control', 'Air Pollution Control', 'IFRS S1', 'IFRS S2', 'climate-related disclosure', 'transition relief', 'reporting requirements', 'business responsibility sustainability report (BRSR)', 'ESG disclosures', 'BRSR', 'Core Standard', 'Industry Standard Report', 'Regulatory Update', 'Financial Report', 'Quarterly Update', 'December 2024']
# Row 0: Final Summary: The text addresses the guidance provided by IND 103 on accounting for business combinations, specifically focusing on the acquisition method and the measurement period for finalizing initial accounting. It emphasizes the need for acquirers to report provisional amounts when the measurement is incomplete. Additionally, it discusses the IFRS sustainability disclosure standards, including IFRS S1 and IFRS S2, which require companies to disclose material information regarding sustainability-related risks and opportunities that could impact cash flow and access to finance. The article also highlights the ISSB's role in establishing a global baseline for sustainability-related disclosures and mentions the upcoming educational materials aimed at helping companies identify and disclose relevant information.
# The text addresses the importance of sustainability-related disclosure standards, emphasizing the need for companies to provide comprehensive information on sustainability risks and opportunities that could impact cash flow and access to finance. It highlights recent regulatory developments in India, particularly from the Securities and Exchange Board of India (SEBI), regarding compliance reports and related party transactions. Additionally, it discusses the measurement period in business combinations under IND 103, focusing on the complexities of accounting for such transactions and the need for provisional amounts in financial statements.
# The text addresses the measurement period in the context of business combinations, emphasizing the importance of provisional amounts and their adjustments within this timeframe. It outlines the acquirer's responsibilities to recognize and measure identifiable assets and liabilities, including noncontrolling interests, based on information available at the acquisition date. The excerpt highlights that the measurement period may extend beyond one year if necessary information is not obtained promptly. It also discusses the potential for adjustments to provisional amounts based on new information or events occurring after the acquisition date, which may require significant judgment. The implications of these adjustments on financial statements and the recognition of goodwill or gains from bargain purchases are also noted.
# The text addresses the complexities of accounting for business combinations, particularly focusing on the recognition of assets and liabilities during the measurement period. It highlights the need for companies to disclose provisional amounts in their financial statements, especially when initial accounting is incomplete. An example is provided where a company acquires another and recognizes a provisional fair value of property, plant, and equipment (PPE) at INR 30 crore, later adjusted to INR 40 crore based on an independent valuation received during the measurement period. The excerpt emphasizes the importance of accurate financial reporting and the adjustments that may arise from new information available after the acquisition date.
# The text discusses the accounting treatment for a business combination involving the acquisition of Company B for INR 983 crore. It highlights the need to determine measurement period adjustments based on fair value assessments, with specific figures such as INR 40 crore as the fair value and INR 30 crore as the provisional value, leading to an additional depreciation of INR 10 crore. The company is required to retrospectively adjust prior year financial information, impacting the carry amount of property, plant, and equipment (PPE) and goodwill as of March 31, 2024. The depreciation expense is noted to increase by INR 1683 lakh. The measurement period is defined as one year following the acquisition date, allowing for adjustments based on new information that may arise. The text emphasizes the importance of comprehensive disclosures in financial statements regarding these adjustments and the rationale behind them.
# The text addresses the importance of sustainability reporting and the disclosure of material information related to sustainability-related risks and opportunities. It emphasizes the need for companies to adjust their financial statements to reflect new information, particularly in the context of IFRS sustainability disclosure standards (IFRS S1 and IFRS S2). The article outlines guidance for identifying and disclosing material information that could affect an entity's prospects, highlighting the significance of making materiality judgments. It also discusses the requirements for companies to provide relevant information to meet the needs of primary users, ensuring that material omissions or misstatements do not obscure critical information.
# The text emphasizes the importance of sustainability-related financial disclosures and the distinct materiality judgement required for these disclosures compared to general purpose financial reports. It highlights that entities must assess whether information is material based on its potential influence on primary user decisions, particularly for potential investors. The excerpt outlines a four-step process for identifying and disclosing material information related to sustainability risks and opportunities, ensuring that such disclosures are clear and distinguishable from other information. The guidance aligns with ISSB standards and underscores the need for entities to consider their specific circumstances, including industry context, when making these assessments.
# The text focuses on the concept of materiality judgement in the context of general purpose financial reports, emphasizing the importance of considering the primary user's decision-making needs. It highlights that these reports should provide relevant information that meets common needs of primary users, particularly potential investors. The assessment of whether information is material involves evaluating its potential influence on user decisions, taking into account the characteristics of primary users and the specific circumstances of the entity, such as its industry context. The excerpt also discusses sustainability-related financial disclosures, which are essential for informing users about sustainability-related risks and opportunities. It outlines a four-step process for identifying and disclosing material information related to sustainability, culminating in the preparation of final sustainability-related financial disclosures. The text indicates that while the definition of material information aligns with ISSB standards and IFRS accounting standards, the judgement for sustainability disclosures is distinct and requires careful consideration to avoid omitting, misstating, or obscuring critical information that could affect user decisions.
# The text outlines a process for identifying and assessing sustainability-related risks and opportunities that may be material for financial disclosures. It emphasizes the importance of recognizing potentially material information in accordance with ISSB standards, particularly focusing on the needs of primary users who rely on this information for decision-making. The first step involves identifying sustainability-related risks and opportunities, with a specific mention of climate-related factors and the need for appropriate disaggregation of information. The text also highlights the necessity of applying judgement in determining the relevance and materiality of the information, considering both quantitative and qualitative factors. The second step involves assessing whether the identified potentially material information meets the threshold for materiality as specified by ISSB standards. The document references the importance of education material in guiding entities through these processes and ensuring compliance with IFRS standards, particularly IFRS S1 and S2, which provide frameworks for sustainability-related disclosures.
# The text discusses the assessment of materiality in the context of sustainability-related risks and opportunities, emphasizing the importance of both quantitative and qualitative factors. Quantitative factors include metrics such as cash flow, resource consumption, return on investment, market share, and GHG emissions, which are used to evaluate materiality thresholds. Qualitative factors, on the other hand, pertain to the entity's governance, stakeholder interactions, and external conditions like geographical location and industry sector. The text highlights that the presence of significant qualitative factors may lower the quantitative threshold for materiality assessment. It also notes that entities must consider a range of possible outcomes and their likelihood when determining the materiality of information related to future events, particularly those that could significantly impact cash flow over time. The ISSB standards are referenced, indicating the need for entities to identify material information based on these considerations.
# The text outlines the process for drafting sustainability-related financial disclosures, emphasizing the organization of material information to ensure clarity for primary users. It highlights the importance of exercising judgment in determining whether to aggregate or disaggregate information, as aggregating may obscure material details. Entities are required to reassess their materiality judgments in light of changing circumstances, both internal and external, that could impact the sustainability-related risks and opportunities they face. The final review of the draft disclosure is crucial to ensure compliance with requirements and to confirm that the information presented is understandable and relevant to the primary user. The text also notes that disclosures should be part of the general-purpose financial report and that entities must disclose material information regardless of specific ISSB standards, focusing on the influence of such information on user decisions.
# The text addresses the importance of sustainability-related financial disclosure, emphasizing the need for entities to provide material information in a manner that is understandable and useful for primary users. It discusses the potential for review processes to lead to the identification and reassessment of material information, suggesting that information previously deemed immaterial could influence user decisions when considered collectively. The excerpt also highlights the role of the ISSB standards in guiding entities to disclose relevant sustainability-related risks and opportunities. Additionally, it mentions a consultation paper issued by the Securities and Exchange Board of India (SEBI) regarding amendments to secretarial compliance reports and related party transactions, seeking public feedback on proposed changes to enhance regulatory compliance. Key amendments include strengthening the requirements for listed entities to submit secretarial compliance reports annually and specifying formats for these reports.
# The text outlines various regulatory requirements and proposals related to secretarial audits and compliance reports under the Companies Act 2013 and LODR regulations. It emphasizes the need for disclosure of the annual secretarial compliance report (ASCR) and the fees paid to secretarial auditors, especially in cases of resignation or removal. The text discusses the approval requirements for related party transactions (RPTs) involving subsidiaries, proposing a monetary threshold of INR 1000 crore for audit committee approval, alongside a percentage-based threshold of 10% of annual standalone turnover. For SMEs, a lower threshold of INR 50 crore is suggested. Additionally, it addresses the need for clarity on the definition of related parties and the applicability of exemptions for wholly owned subsidiaries. The proposal includes standardizing the format for disclosures to ensure minimum information is provided to shareholders during annual general meetings regarding the appointment or reappointment of statutory and secretarial auditors.
# The text discusses the SEBI's proposal for amendments related to secretarial provisions and the introduction of an Industry Standard Recognition Manual aimed at facilitating compliance for various regulated entities, including market infrastructure institutions and mutual funds. The manual outlines guidelines for recognizing industry standards and includes a framework for compliance with regulatory directives. Key points include the formation of an Industry Standard Forum (ISF) to develop specific standards and checklists for implementation. The manual emphasizes the need for uniformity in compliance and allows SEBI to modify guidelines as necessary. Additionally, it addresses the requirements for related party transactions (RPTs) as per SEBI's LODR regulations, specifying that material RPTs must be approved by the audit committee and shareholders. A circular issued on February 14, 2025, introduces minimum information standards for audit committee review of RPTs, effective from April 1, 2025. The text highlights the role of KPMG Assurance Consulting in this context and the importance of regulatory compliance for listed entities.
# The text discusses various regulatory requirements and standards related to financial audits, related party transactions, and environmental social governance (ESG) ratings. It highlights the need for minimum information disclosure for audit committees regarding RPTs, specifying a two percent net worth threshold and a five percent average absolute profit/loss over the last three audited financial statements. The text also mentions the issuance of a master circular by SEBI on ESG rating providers, mandating that significant events affecting a company's ESG profile be reviewed within ten days, although concerns about feasibility led to an extension of the review timeline to 45 days. Additionally, it addresses compliance deadlines for private companies regarding the dematerialisation of securities, extending the deadline to June 30, 2025. The Quality Review Board (QRB) is mentioned as responsible for ensuring compliance with audit standards.
# The text outlines the role of Asset Reconstruction Companies (ARCs) in managing non-performing assets (NPAs) within the financial system, emphasizing the challenges they face in recovering dues from borrowers. It highlights recent guidelines issued by the Reserve Bank of India (RBI) on January 20, 2025, which aim to streamline the settlement procedures for ARCs. Key changes include the requirement for board-approved settlement policies, categorization of dues based on the principal amount, and the establishment of an Independent Advisory Committee (IAC) for proposals exceeding INR 1 crore. The guidelines also stipulate that settlements must comply with existing laws and regulations, and that consent from relevant judicial authorities is necessary. Additionally, the text references the Institute of Chartered Accountants of India (ICAI) and its guidance on noncompliance issues, indicating a focus on quality control and audit standards in the context of financial reporting and compliance.
# The text outlines regulatory updates from the Reserve Bank of India (RBI) and the Insurance Regulatory Development Authority of India (IRDAI) regarding private placement nonconvertible debentures (NCDs) with a maturity of one year, specifically for nonbanking financial companies (NBFCs) and housing finance companies (HFCs). It mentions amendments to guidelines that will apply mutatis mutandis to HFCs, as well as the introduction of a regulatory sandbox framework by IRDAI aimed at enhancing innovation and operational efficiency in the insurance sector. Key points include the consolidation of regulations to strengthen data governance and confidentiality, and the requirement for regulated entities to adopt a data governance framework. Additionally, the text discusses amendments to meeting regulations to improve operational flexibility and efficiency. The mention of artificial intelligence (AI) and machine learning (ML) indicates a focus on technological advancements within market infrastructure institutions (MIIs) and the broader financial sector.
# The text outlines various regulatory updates and guidelines from the Securities and Exchange Board of India (SEBI) and the Ministry of Environment, Forest and Climate Change (MoEFCC). SEBI is focusing on the regulation of artificial intelligence and machine learning (AI/ML) tools used by regulated entities, emphasizing the importance of privacy, security, and compliance with applicable laws. A consultation paper has been issued to review the AIF Regulation 2012, addressing concerns about investment opportunities in unlisted debt securities, proposing that Category II Alternative Investment Funds (AIFs) can invest up to 50% of their funds in unlisted securities. Additionally, MoEFCC has released new guidelines for controlling water and air pollution, aiming to streamline the consent process for industrial plants that may cause pollution. These guidelines are part of the broader regulatory framework to ensure accountability and compliance in both financial and environmental sectors.
# The text discusses the International Financial Reporting Standards (IFRS) S1 and S2, which set requirements for climate-related disclosures and sustainability-related risks and opportunities. The ISSB (International Sustainability Standards Board) aims to assist companies in implementing these standards, including a transition relief that allows companies to disclose climate-related risks and opportunities in a more manageable scope during their first year of reporting. The IFRS Foundation plans to publish a guide by January 30, 2025, to help companies understand how to report climate-related information in accordance with ISSB standards. Additionally, the text mentions the Securities and Exchange Board of India (SEBI) and its introduction of key changes to the Business Responsibility and Sustainability Report (BRSR) framework, which mandates the top 1000 listed entities in India to prepare such reports. SEBI's framework includes core ESG disclosures and assurance requirements related to the value chain. The text emphasizes the importance of accurate and timely information while noting that companies should seek professional advice for specific situations.
# The text discusses the Business Responsibility and Sustainability Reporting (BRSR) framework, emphasizing the facilitation of ease in business through the SEBI circular dated December 20, 2024. It highlights the introduction of the BRSR Core Standard aimed at standardizing and easing the implementation of disclosures. The first note provides an overview of key changes introduced by SEBI regarding the BRSR report. Additionally, it mentions a quarterly update publication summarizing important financial reports and regulatory updates relevant to the quarter ending December 31, 2024. The involved regulatory bodies include the Securities and Exchange Board of India (SEBI), the Reserve Bank of India (RBI), and the National Financial Reporting Authority (NFRA), along with the Ministry of Environment, Forestry, and Climate Change, and the Institute of Chartered Accountants of India (ICAI).
# Row 1: Food and Nutritional Security in India → Category: India (Country), Niche: Agricultural Policy
#  12%|█▏        | 2/17 [02:09<15:03, 60.26s/it]
# Row 1: Key Themes: ['Food Security', 'Public Policy', 'Nutrition', 'Sustainable Agriculture', 'Technology Innovation', 'Collaboration', 'Nutritional Security', 'Multistakeholder Approach', 'Agricultural Sustainability', 'Child Malnutrition', 'Nutritional Access', 'School Meal Programs', 'Micronutrient Fortification', 'Child Health and Development', 'Local Agriculture Support']
# Row 1: Recurring Topics: ['Public Distribution System (PDS)', 'Malnutrition', 'Chronic Undernourishment', 'Digital Reform', 'Smallholder Farmers', 'Community Participation', 'Zero Hunger', 'Food Waste', 'India', 'Hunger', 'Undernutrition', 'Global Hunger Index', 'Food Distribution', 'Supplementary Nutrition', 'School Feeding Programs', 'Fortified Milk', 'Midday Meal Scheme', 'Ragi and Millet', 'Nutritional Education', 'Anaemia Prevention', 'Poshan Abhiyaan', 'Government Initiatives', 'School Meal Programs', 'Fortified Foods', 'Local Agriculture', 'Technology in Nutrition Tracking', 'Food Subsidy', 'Nutritional Status', 'Digitalization', 'Leakage', 'Smart Ration Card', 'Aadhaar-based Authentication', 'Food Security', 'Transportation Challenges', 'Technology Integration', 'One Nation One Ration Card (ONORC)', 'Fair Price Shops (FPS)', 'Pradhan Mantri Garib Kalyan Anna Yojana (PMGKAY)', 'Food Security Act', 'Doorstep Delivery of Ration', 'Food Grain Distribution', 'Economic Disruption', 'Migrant Workers', 'Technology Infrastructure', 'Biometric Authentication', 'Agricultural Imports', 'Food Production Targets', 'Pulse Production', 'Price Support Schemes', 'Agricultural Practices', 'Climate Change', 'Market Price Monitoring', 'Subsidies for Seeds and Fertilizers', 'High Yield Variety Seeds', 'Crop Insurance', 'public service', 'government', 'client market']
# Row 1: Final Summary: Food security is a critical aspect of India's public policy, with the country ranking 105th out of 127 in the 2024 Global Hunger Index, highlighting challenges in hunger and malnutrition. Approximately 194.6 crore people, or 134 million, are chronically undernourished. Strengthening the Public Distribution System (PDS) and implementing digital reforms are key strategies to achieve zero hunger. Sustainable agriculture practices, such as climate-resilient farming and crop diversification, are essential for long-term food security. Nutrition, particularly for vulnerable groups like children and pregnant women, is addressed through government programs like the Midday Meal Scheme. Technology innovations, including AI and blockchain, are utilized to improve food supply chains and reduce waste. Collaboration among government, private sectors, NGOs, and international agencies is necessary to scale successful food production and distribution models. Raising awareness about sustainable consumption and reducing food waste are also vital for enhancing food security in India.
# The text highlights the critical issue of food and nutritional security in India, emphasizing the need for a multistakeholder approach to address gaps in access and distribution. Despite India's strong food production capabilities, the Global Hunger Index (GHI) ranks it 105th out of 127 countries, with 1946 crore people (13.4%) chronically undernourished. The prevalence of malnutrition is alarming, with 37% of children under five being undernourished, 35.5% stunted, and 18.7% wasted. The Integrated Child Development Services (ICDS) program aims to improve health and nutrition for children and pregnant women. The text also discusses the importance of school feeding programs, such as the rebranded Pradhan Mantri Poshan Shakti Nirman (PM Poshan), which serves free lunches to over 12.169 crore school children annually, addressing hunger and promoting local food production. The need for improved infrastructure, technology, and access to food is emphasized to combat undernutrition and achieve the Sustainable Development Goals (SDGs) related to quality education and zero hunger.
# The text highlights various initiatives aimed at improving nutritional access for children through school meal programs. It discusses the importance of micronutrient sufficiency, with examples from countries like the USA, Brazil, Finland, and Japan. Specific measures include the introduction of fortified milk and the midday meal scheme in India, which benefits millions of students, including 366 lakh primary school students and 15 lakh junior college students. The text also mentions the Poshan Abhiyaan, which aims to combat anaemia among pregnant and lactating women, impacting 694 lakh pregnant women and 425 lakh lactating women. The emphasis is on incorporating local agriculture, nutrition education, and diversified diets, including ragi and millet, to enhance child health and prevent nutritional deficiencies.
# The text highlights various initiatives aimed at improving child nutrition through school meal programs across different countries, including the USA, Brazil, Finland, and India. It discusses the incorporation of nutritional education into meal programs to promote healthy eating habits and balanced diets. Specific measures include the fortification of foods such as salt and cooking oil, and the introduction of fortified milk in pilot projects targeting 445 lakh children in Odisha by January 2025. The Karnataka government plans to introduce ragi milk thrice a week in schools, while Andhra Pradesh aims to extend its midday meal scheme to benefit 15 lakh junior college students in addition to 366 lakh primary school students. The text also mentions the Poshan Abhiyaan initiative, which has supported 694 lakh pregnant women and 425 lakh lactating women since 2018 to combat anaemia. Furthermore, it emphasizes the use of technology, such as the Poshan Tracker, to enhance the efficiency of these nutrition programs and develop regional meal plans to address micronutrient deficiencies.
# The article highlights India's efforts to improve nutritional status and food security through the Public Distribution System (PDS) and various initiatives under the National Food Security Act (NFSA) 2013. It notes that 74% of the population cannot afford a healthy diet, with 39% lacking a nutrient-adequate diet. The PDS aims to provide subsidized food grains to 75% of the rural and 50% of the urban population, covering 806.7 million people. The Antyodaya Anna Yojana targets the poorest households. However, PDS faces challenges such as leakage, which decreased from 41.7% in 2011 to 22% in 2022-26, yet an estimated 28 million metric tons of food grains are still lost due to theft, waste, and poor handling. The introduction of Smart PDS aims to leverage technology, including electronic point of sale (EPOS) devices and Aadhaar-based authentication, to enhance transparency and efficiency. The initiative also focuses on modernizing the supply chain through GPS tracking and inventory optimization to address transportation and storage challenges, particularly in rural areas. The article emphasizes the need for investment in storage and transportation facilities to ensure better food distribution.
# The text highlights various initiatives aimed at improving food security and accessibility in India, particularly for vulnerable populations and migrant workers. The One Nation One Ration Card (ONORC) scheme, initiated in 2019, allows beneficiaries to access fair price shops (FPS) across the country, reducing mobility costs and ensuring portability of ration cards. The Pradhan Mantri Garib Kalyan Anna Yojana (PMGKAY) provided free food grains during the COVID-19 pandemic from April 2020 to December 2022. The text also discusses the importance of technology, such as biometric authentication and robust ePOS devices, in enhancing the uptake of these schemes. Additionally, it mentions various state-level initiatives for doorstep delivery of rations, including Andhra Pradesh and Punjab. The text emphasizes the need for improved food production, with targets set under the National Food Security Mission (NFSM) for staple crops like rice (1 crore MT), wheat (80 lakh MT), and pulses (40 lakh MT). It also notes India's heavy dependence on agricultural imports, particularly for pulses and vegetable oils, which poses risks to food security, with agricultural import values reaching USD 3,300 crore, including USD 1,710 crore for vegetable oil.
# The text highlights India's significant increase in pulse imports by 44% in 2023 compared to 2022, emphasizing the need for improved domestic agricultural practices and infrastructure to ensure food security. It discusses strategies to tackle inflation and food insufficiency, including close monitoring of food prices, agricultural partnerships, and initiatives like the Price Support Scheme (PSS) and Price Stabilisation Fund (PSF) to control price volatility and maintain buffer stocks. The National Food Security Mission (NFSM) aims to assist farmers through high yield variety seed demonstrations, crop insurance, and subsidies for seeds and fertilizers. The text also stresses the importance of promoting climate-resilient agricultural practices and technology to mitigate climate change risks. A holistic approach is called for to address the diverse needs of the population, leveraging existing programs and fostering community participation to achieve zero hunger and improve nutrition. The operational guidelines for the NFSM are set to be accessed by February 13, 2025, as part of India's 12th five-year plan.
# The text highlights key figures in public service and client market sectors, specifically mentioning Nilachal Mishra as a partner and head of government public service, and Akhilesh Tuteja as the head of client market.
# Row 2: Financial Crime Bulletin → Category: Risk Regulation, Niche: Financial Compliance
#  18%|█▊        | 3/17 [02:22<09:00, 38.60s/it]
# Row 2: Key Themes: ['Financial Crime', 'Regulatory Initiatives', 'Technological Integration', 'Fraud Prevention', 'Compliance Frameworks']
# Row 2: Recurring Topics: ['Anti-Money Laundering (AML)', 'Corporate Transparency Act (CTA)', 'Beneficial Ownership Information', 'Fraud Risk Management', 'Financial Institutions', 'Regulatory Compliance', 'Financial Crime Prevention', 'Corporate White-Collar Crime', 'Internal Risk Assessment', 'Due Diligence', 'Digital Payment Advancements', 'Whistleblower Policy', 'Surveillance Systems']
# Row 2: Final Summary: Financial crime is an evolving issue, with an estimated USD 31 trillion in illicit funds and USD 485.6 billion in fraud and scams expected in 2023. Technological advancements complicate the landscape for financial institutions (FIs). Key regulatory initiatives include the Corporate Transparency Act (CTA), effective January 1, 2024, requiring companies to file beneficial ownership information by January 1, 2025. The U.S. Department of Justice will introduce a pilot program for non-prosecution agreements for individuals disclosing white-collar crimes. The Reserve Bank of India issued guidelines for internal risk assessments to combat money laundering and terrorist financing. The Securities and Exchange Board of India (SEBI) updated AML compliance requirements for market intermediaries to enhance fraud detection and prevention. Overall, the text emphasizes the need for robust frameworks and compliance measures to address the challenges posed by financial crime.
# The text outlines various regulatory measures and guidelines aimed at combating financial crimes, particularly focusing on anti-money laundering (AML) and fraud risk management. Key dates include the introduction of an AML compliance program on April 15, 2024, and updates from the Securities and Exchange Board of India (SEBI) on June 6, 2024, which emphasize enhanced due diligence and transaction monitoring. The Reserve Bank of India (RBI) is set to issue comprehensive guidelines on October 10, 2024, to streamline internal risk assessments for banks and non-banking financial companies (NBFCs). Additionally, a master direction for fraud risk management will be implemented on July 15, 2024, providing a framework for early detection and reporting of fraud. SEBI's measures introduced on July 4, 2024, focus on broker mechanisms for fraud prevention and detection, with compliance timelines ranging from January 1, 2025, to April 1, 2026. The text also highlights the evolving landscape of financial crime due to advancements in digital payments and technology, necessitating a proactive approach to stay ahead of emerging threats.
# Row 3: KPMG global tech report – industrial manufacturing insights → Category: Technology, Niche: Industrial IoT
#  24%|██▎       | 4/17 [03:54<12:59, 59.97s/it]
# Row 3: Key Themes: ['Digital Transformation', 'Operational Efficiency', 'AI Adoption', 'Workforce Upskilling', 'Cybersecurity', 'Interoperability', 'Technology Innovation', 'Value Creation', 'Risk Management', 'AI and Quantum Computing', 'Industry Insights', 'Technology Investment', 'Organizational Strategy', 'Competitive Advantage', 'Strategic Implementation', 'AI and Automation', 'Organizational Agility', 'Profitability', 'Technology Adoption', 'Tech Debt', 'Investment Strategies', 'Leadership in Technology']
# Row 3: Recurring Topics: ['Industrial Manufacturing', 'KPMG Global Tech Report', 'Digital Maturity', 'Supply Chain', 'Procurement', 'Finance', 'Return on Investment (ROI)', 'Data Strategy', 'KPMG Global Tech Report 2024', 'Technology Professionals', 'Evidence-Based Decision Making', 'Senior Leadership', 'Generative AI', 'Quantum Computing', 'High Performers', 'Fear of Missing Out (FOMO)', 'Technology Adoption', 'Market Trends', 'XaaS', 'Cloud Computing', 'Cybersecurity', 'Data Analytics', 'Employee Feedback', 'Customer Feedback', 'Profit Increase', 'Tech Impact on Profitability', 'Digital Transformation Efforts', 'XaaS Technology', 'AI and Automation', 'Tech Debt', 'Investment in New Technology', 'Evaluation of Technology', 'Proactive Approach', 'Partnership Ecosystems', 'Value Measurement', 'Technology Investment Evaluation', 'Sustainability', 'Social Responsibility', 'Data Maturity', 'Data-Driven Decision Making', 'Customer Experience', 'AI Solutions', 'Tech Initiative Alignment', 'Tech Investment', 'Proficiency in Data Management', 'Business Growth Metrics', 'Digital Transformation', 'Performance Management', 'Cost Forecasting', 'Stakeholder Alignment', 'Data Security Governance', 'Value Tracking Metrics', 'Risk Management', 'AI Implementation', 'Data Security', 'Data Governance', 'Data Accessibility', 'Data Culture', 'Data Investment', 'Trust and Security', 'Data Integrity', 'Employee Training', 'Automation', 'Data Hygiene Audit', 'Risk Aversion', 'Business Continuity Planning', 'Employee Wellbeing', 'Productivity Improvement', 'AI Adoption', 'Workforce Anxiety', 'Trust in AI', 'Ethical Concerns', 'Employee Empowerment', 'Strategic Leadership', 'Maturity Level of AI Adoption', 'Use Cases of AI', 'Global AI Investment', 'AI Experimentation', 'Decentralized Approach', 'Centralized Approach', 'Collaboration', 'Operational Efficiency', 'Value Optimization', 'Employee Involvement', 'Data Infrastructure', 'AI Governance', 'Data Quality', 'Enterprise Alignment', 'AI Transformation', 'Ethical Use of AI', 'AI Integration', 'Skill Gap', 'Predictive Analytics', 'High-Performing Organizations', 'Employee Contribution', 'Innovation Centers of Excellence (CoEs)', 'Data-Centric Approach', 'AI Value Optimization', 'Data Management', 'Technical Debt Management', 'Collaboration and Partnerships', 'Continuous Learning', 'Technological Innovation', 'AI (Artificial Intelligence)', 'Cloud Technology', 'KPMG Services', 'Global Delivery Network']
# Row 3: Final Summary: The KPMG Global Tech Report 2024 highlights the imperative of digital transformation in industrial manufacturing, emphasizing the need for enhanced operational efficiency, quality control, and sustainability. The report reveals that 76% of industrial manufacturing firms are willing to adopt cutting-edge technology, with 34% achieving ROI from multiple AI use cases. However, significant maturity gaps in supply chain, procurement, and finance hinder full digital potential. Recommendations include improving data strategies for seamless integration, upskilling the workforce, and prioritizing cybersecurity measures. The survey involved 2,450 technology leaders across 26 countries, with a focus on evidence-based decision-making to align technology investments with broader business strategies.
# The text discusses the rapid pace of technology innovation and its implications for organizations, emphasizing the importance of value creation and risk management. It highlights insights from the KPMG Global Tech Report 2024, which surveyed 2,450 technology professionals across various industries. Key recommendations include optimizing value through evidence-based decision-making and delivering resilient solutions, particularly in the context of generative AI and quantum computing. The report features perspectives from senior leaders in technology, underscoring the need for a measured approach to technology investments while navigating the challenges and opportunities presented by these advancements.
# The text discusses the challenges and strategies organizations face in digital transformation, emphasizing the importance of high performers who represent less than 10% of tech professionals. It highlights the need for evidence-based decision-making to optimize technology investments, particularly in the context of rapid technological advancements and the fear of missing out (FOMO). The report notes that 78% of executives worry about keeping pace with change, while 80% cite risk aversion as a barrier to adopting new technologies. In 2024, the influence of competitor actions on tech choices has decreased, with 89% of organizations looking to third-party guidance and 83% relying on in-house trials or proofs of concept. The text underscores the necessity for a balanced approach to investment decisions to avoid misguided initiatives and ensure sustainable progress.
# The KPMG Global Tech Report 2024 highlights key motivations for technology investment among organizations, emphasizing the importance of evidence-based decision-making and resilient solutions. The report ranks various factors influencing tech investment, with 'guidance from third parties' leading at 63%, followed by 'in-house trials/proofs of concept' at 89%, and 'competitor market adoption' at 56%. The report notes a significant focus on XaaS technologies, including public cloud and multicloud solutions, with 86% of organizations prioritizing agility and cost reduction. Cybersecurity (68%) and AI automation (65%) are also critical areas of investment. The text indicates a shift towards proactive implementation strategies, particularly in regions like India and China, and underscores the need for executive buy-in to overcome barriers to progress. Overall, the report suggests that many organizations are aligning technology with core business strategies to achieve profit uplift.
# The text highlights the significant impact of digital transformation on profitability, with 50-60% of organizations reporting positive effects from technology investments over the past 24 months. Key metrics include a 25 percentage point rise in average profitability linked to tech initiatives and 72% of executives agreeing that digital transformation leads to business value. The text emphasizes the importance of addressing tech debt, with 57% of organizations acknowledging that flaws in foundational systems disrupt operations. It also notes that 74% of organizations plan to invest in new technologies rather than enhancing existing systems, indicating a shift towards XaaS platforms to reduce complexity. Overall, the focus is on optimizing technology investments to deliver value and overcome challenges in digital transformation.
# The text highlights the importance of digital transformation and the strategic evaluation of technology investments within organizations. Leaders are 23 percentage points less likely to worry about keeping pace with change compared to non-leaders, and 83 percent of leaders continuously evaluate the business value of their tech investments. The text emphasizes the need to address tech debt, which is a significant challenge for organizations, with 57 percent reporting that flaws in foundational systems disrupt operations weekly. Additionally, 93 percent of leaders plan to expand their ecosystem partnerships, contrasting with 70 percent of mainstream organizations. The study indicates that top performers are 53 percent more likely to strategically evaluate their tech investment portfolios to align with long-term goals, underscoring the necessity for organizations to balance immediate technological advancements with long-term planning.
# The text highlights the importance of strategically evaluating technology investments to align with long-term goals, with 53% of organizations actively doing so, compared to 41% in others. A significant 70% of executives aim for technology initiatives to target sustainability and social responsibility, indicating a shift towards broader purposes beyond financial gains. The report emphasizes the necessity of data maturity, with high performers frequently engaging in data-centric evaluations as an effective tactic for achieving quick wins in tech investments. Organizations with strong data management practices are 18 percentage points less likely to experience disruptions due to foundational system flaws. The text also underscores the need for evidence-based decision-making, with a call for businesses to empower employees through data-driven approaches to redesign work processes. Key recommendations include optimizing value through effective data analytics and ensuring data interoperability, accessibility, and governance to extract meaningful insights. The overall message stresses the integration of technology into business strategies to enhance customer experience and operational resilience.
# The text discusses the importance of data maturity and effective use of customer feedback in driving business growth and technology investment. It highlights that 52% of respondents have a high level of data proficiency, with cloud platforms playing a key role in enhancing this proficiency. The text emphasizes the need for organizations to measure value through quantifiable metrics, including financial metrics like cost-to-serve and profitability, as well as customer-centric metrics such as customer satisfaction and growth. It notes that 78% of executives believe their businesses fail to utilize customer feedback effectively, which may stem from communication issues between front and back offices. The text also mentions the significance of predictive modeling and data-backed measurements in identifying growth opportunities and mitigating risks, ultimately aiming to optimize value and support proactive decision-making in organizations.
# The text emphasizes the importance of effective investment performance and informed decision-making in digital transformation projects. It highlights that 73% of executives believe accurate cost forecasting is crucial, while 67% focus on preventing hidden costs that could disrupt their digital transformation journey. High-performing organizations are more likely to use both qualitative and quantitative metrics to establish causal trends and utilize real-time data for continuous performance monitoring. They regularly review and update value-tracking metrics to stay aligned with market changes, making data-driven decisions that support long-term goals. The text notes that 53% of leaders evaluate their tech investment portfolios strategically, with a 12 percentage point advantage over non-leaders. Additionally, 90% of leaders achieve consensus among stakeholders efficiently, compared to 18 percentage points less in other organizations. Cybersecurity is also a significant concern, with 87% of leaders confident in measuring the value of their tech investments against risk. The text concludes by stressing the need for robust data-driven processes and strong data security governance to enhance organizational resilience and ensure compliance.
# ...
# The text discusses various applications of automation across different business processes, including sentiment analysis for customer feedback, background verification for new hires, and the creation of job descriptions. It highlights the role of agents in automating tasks such as candidate sourcing, employee engagement, and managing asset lifecycles. Additionally, it addresses the importance of disaster recovery protocols and the need for regular updates to ensure readiness. The text emphasizes the use of technology to enhance efficiency, improve search engine optimization (SEO) performance, and drive organic traffic through better content management and keyword optimization.
# The text discusses the integration of automation agents in the recruitment process, emphasizing their role in enhancing efficiency and accuracy in candidate profile screening and job description creation. It highlights how these agents can reduce time-to-hire, improve recruiter productivity, and ensure consistent decision-making without bias. The automation tools optimize the search for potential candidates by using keywords and filtering resumes to identify the best fits based on qualifications and experience. Additionally, the text addresses the importance of employee engagement and performance management, detailing how automation can streamline HR administration, compliance, and employee development activities. The overall aim is to create a more efficient talent acquisition process while maintaining alignment with organizational standards and improving the employee experience.
# The text discusses the integration of AI and automation in HR functions, emphasizing the need for a self-service payroll benefit management portal and personalized training recommendations. It highlights the importance of governance frameworks to ensure ethical AI implementation, addressing risks such as data privacy and regulatory compliance. The text also notes the shift towards autonomous agents handling tasks alongside human counterparts, which requires a new skill set for managing a blended workforce. Organizations must prepare for the evolving role of humans in high-skill positions while ensuring that AI systems operate transparently and fairly. Regular compliance audits and adherence to ethical guidelines are essential to mitigate legal risks. The overall transformation aims to enhance efficiency, drive innovation, and unlock new revenue channels, while balancing the need for innovation with compliance and ethical considerations.
# The text emphasizes the importance of a development governance model to manage organisational and societal risks, enabling continuous innovation. It highlights the need for leaders to create a responsible AI framework to integrate AI into business operations effectively. PwC's role is underscored in helping organizations adopt automation solutions that redefine business models and enhance customer experiences while managing potential risks. The document also mentions PwC's commitment to quality assurance and advisory services across its global network, which includes 151 countries and 360,000 people. It stresses the necessity for professional advice when making decisions based on the information provided, indicating that the content is subject to change and should not be solely relied upon for critical decisions.
# Row 16: Deals at a glance: Annual review 2024 → Category: Economy and Growth, Niche: Market Trends
# 100%|██████████| 17/17 [23:12<00:00, 81.90s/it]
# Row 16: Key Themes: ['Economic Growth', 'Investment Trends', 'Mergers and Acquisitions', 'Private Equity', 'Market Dynamics', 'Domestic Transactions', 'Market Trends', 'Investment in Technology', 'Healthcare Sector Growth', 'Private Equity Activity', 'Capital Investment', 'Initial Public Offerings (IPOs)', 'Sector Consolidation']
# Row 16: Recurring Topics: ['Deal Volume', 'Transaction Value', 'Private Equity Investment', "India's GDP Growth", 'Foreign Direct Investment', 'Deal Value', 'Domestic Deals', 'Technology Sector', 'Healthcare Sector', 'Average Ticket Size', 'Quarterly Trends', 'Large Deals', 'Energy Sector', 'Entertainment Sector', 'Healthcare', 'Renewable Energy', 'Strategic Investments', 'Domestic Mergers', 'IPOs', 'Small and Medium Enterprises (SMEs)', 'Initial Public Offering (IPO)', 'Mainboard IPO', 'SME IPO', 'Investment in Real Estate', 'Private Credit', 'Nifty 50 Index', 'Global Investment Climate', 'Credit Growth', 'Market Trends', 'Insolvency and Bankruptcy Code (IBC)', 'National Company Law Tribunal (NCLT)', 'Insolvency Bankruptcy Board of India (IBBI)', 'Corporate Insolvency Resolution Process (CIRP)', 'Mediation in insolvency proceedings', 'Voluntary liquidation', 'Cross-border insolvency', 'Operational creditors', 'Human capacity gap in NCLT', 'Appointment of tribunal members', 'IBC (Insolvency and Bankruptcy Code)', 'GDP Growth', 'Investment Growth', 'Government Consumption', 'Private Final Consumption Expenditure (PFCE)', 'Gross Fixed Capital Formation (GFCF)', 'Gross Value Added (GVA)', 'Sectoral Growth Rates', 'Industrial Production Index (IIP)', 'Manufacturing Growth', 'Mining Growth', 'Electricity IIP', "Purchasing Managers' Index (PMI)", 'Passenger Vehicle Sales', 'Two-Wheeler Sales', 'Retail Sales', 'Consumer Price Index (CPI)', 'Wholesale Price Index (WPI)', 'Unemployment Rate', 'FMCG Growth', 'Petrol Consumption', 'Inflation', 'Domestic Traffic Growth', 'Corporate Deals', 'Megadeals', 'Private Equity (PE) Exit', 'Artificial Intelligence (AI)', 'Geopolitical Unpredictability', 'Interest Rates', 'Refinancing Challenges', 'Market Valuation', 'Investment Outlook for 2025', 'Professional Advice']
# Row 16: Final Summary: In 2024, India's economic landscape showed mixed performance with GDP growth slowing to 5.4% in Q2 FY25 from 6.7% in Q1 FY25. Despite challenges, India is projected to be the fastest-growing G20 economy with a 7% growth rate, driven by robust domestic demand. The deal landscape experienced a significant revival, with a 42% increase in overall transactions, totaling 2,606 deals, and a 52% rise in mergers and acquisitions. Private equity investments also surged, with a 34% increase in transaction volume and a total disclosed deal value reaching USD 1.117 trillion, reflecting strong market confidence. The retail and consumer sectors led in transaction volume, while tech innovation and advancements in e-commerce and fintech were highlighted as key areas of growth. The real estate sector showed positive credit growth, and regulatory amendments under the Insolvency and Bankruptcy Code (IBC) contributed to improved deal structures.
# In Q4 2023, domestic transaction volume nearly doubled compared to previous quarters, with a total of 800 domestic deals valued at USD 565 billion. The trend indicates a strategic focus on consolidating market share and expanding within existing markets, with 70% of total deals in 2024 being domestic. The average ticket size for transactions was USD 91 million, while private equity (PE) ticket sizes dropped to USD 34 million. The retail and consumer sectors led with 418 transactions worth USD 99 billion, while the technology sector followed with 352 deals valued at USD 63 billion. The healthcare sector also saw significant growth, with 183 deals valued at USD 53 billion, driven by advancements in medical technology. Overall, 2024 wrapped up with 2,606 announced deals totaling USD 112 billion, reflecting a strong emphasis on domestic growth and investment in high-growth sectors.
# The text highlights significant trends in mergers and acquisitions, noting that 19 deals exceeded USD 1 billion, accounting for 34% of total disclosed deal value. Key sectors include oil and gas, with notable mergers like Gujarat State Petronet and Gujarat State Petroleum Corp, and the entertainment sector with a joint venture between Reliance Industries and Disney. The outlook for 2024 emphasizes consolidation in technology and renewable energy, with expectations of continued activity in various sectors, including consumer and pharma. The report also mentions a record year for IPOs, with 91 mainboard IPOs raising INR 159,784 crore, three times the amount raised in 2023. The SME segment saw a significant increase, with 240 IPOs raising INR 8,761 crore, marking a sixfold jump in average deal size compared to previous years.
# In 2024, India experienced a record-breaking year for IPOs, with 91 mainboard IPOs raising INR 159,784 crore, significantly higher than the INR 49,436 crore raised in 2023. The SME segment also saw a notable increase, with 240 IPOs raising INR 8,761 crore. The average deal size for IPOs doubled to INR 1,756 crore compared to INR 867 crore in 2023. The Nifty 50 index showed a year-on-year growth of 9%, although it faced an 8% drop towards the end of the year, indicating potential volatility. The private credit market also thrived, with a total transaction volume of USD 10 billion and an average deal size of USD 29 million. Real estate investments accounted for 28% of total deal volume, while sectors like renewables and healthcare gained interest. The overall market sentiment was mixed, with global indices like the S&P 500 showing stronger growth compared to Indian markets. The analysis highlighted a shift in investment strategies, with non-banking financial companies and family offices increasingly participating in the private credit space.
# The text discusses the evolving landscape of insolvency and bankruptcy in India, particularly focusing on the Insolvency and Bankruptcy Code (IBC) and the role of the National Company Law Tribunal (NCLT) and the Insolvency Bankruptcy Board of India (IBBI). Key issues include the need for clarity on statutory setoff in the Corporate Insolvency Resolution Process (CIRP), the introduction of mediation in insolvency proceedings, and the challenges posed by operational creditors. The IBBI aims for continuous improvement in the insolvency framework, with proposals for standardization and enhanced oversight, particularly in voluntary liquidation cases. The text highlights the importance of addressing the human capacity gap within the NCLT and emphasizes the need for timely appointments of tribunal members with domain expertise. It also notes the potential for cross-border insolvency issues and the impact of the Digital Personal Data Protection Act 2023 on insolvency proceedings. The year 2024 is seen as a pivotal time for these developments, with expectations for improved outcomes and infrastructure in the insolvency process.
# The text discusses the performance of the Indian economy, highlighting the challenges and expectations surrounding the Insolvency and Bankruptcy Code (IBC) as it evolves to address shortcomings. It notes a decline in GDP growth, with figures showing a fall to 5.5% in Q2 FY25 from 8.1% in Q2 FY24, and a dip in investment growth to 5.4% in Q2 FY25 compared to 7.5% in Q1 FY25. Private final consumption expenditure (PFCE) is reported at 55.8% in Q2 FY25, while government final consumption expenditure (GFCE) shows a significant increase to 9.5%. Gross fixed capital formation (GFCF) is at 33.5%, indicating a recovery in capital investments. The gross value added (GVA) grew by 5.6% in Q2 FY25, with sectoral contributions varying: agriculture grew by 1.4%, manufacturing by 17.3%, and construction by 9.0%. The text emphasizes the need for a balanced approach to stakeholder interests and the importance of navigating the complex legal and regulatory environment as the IBC continues to develop.
# The text provides an overview of various economic indicators for October and November 2024, highlighting the Industrial Production Index (IIP) growth rates: mining at 0.9%, manufacturing at 4.1%, and electricity at 2%. The Purchasing Managers' Index (PMI) for manufacturing dropped to 56.5, while the service PMI slightly declined to 58.4. Passenger vehicle sales saw a year-over-year decline of 13.7% and a month-over-month decline of 33.4% due to weak market sentiment. In contrast, two-wheeler sales increased by 15.8% in November 2024, driven by rural demand. Retail sales for two-wheelers were reported at 575,000 units. The CPI inflation was moderate at 5.48%, with a 14-month high of 6.2% in October 2024. The unemployment rate decreased to 8% in November 2024. FMCG growth was weak, while petrol consumption reached a six-month high, reflecting a 9.6% year-over-year increase. Overall, the economic indicators suggest mixed performance across sectors, with some areas showing growth while others face challenges.
# Inflation rates have shown mixed trends, with a reduction in overall inflation to 9% in November from 10.87% in October, while edible oil prices are rising due to costly imports and high demand during festive seasons. The aviation sector in India recorded a significant increase in passenger traffic, with a 143% year-over-year growth in domestic traffic and a record of 5 lakh domestic passengers on a single day. The wholesale price index (WPI) inflation eased to 18.9% in November from 23.6% in October, driven by a slowdown in food prices, particularly vegetables and fruits. The corporate deal landscape is evolving, with a notable increase in deals exceeding USD 1 billion, rising from 430 in 2023 to 500 in 2024, particularly in sectors like technology, energy, and banking. The focus on megadeals is growing, with private equity firms seeking large transactions amid high valuations and reliance on equity financing. The report highlights the importance of corporate divestitures and acquisition opportunities in sectors such as e-commerce, renewable energy, and AI. Additionally, the role of AI as a catalyst for business transformation and investment attraction is emphasized, alongside the need for dealmakers to navigate potential market uncertainties.
# The text discusses the challenges posed by geopolitical unpredictability and policy changes, which create persistent difficulties in the financial landscape. It highlights how central banks lowering interest rates may not effectively decrease inflation, leading to long-term rate rises that complicate refinancing efforts and reduce potential profits. The high market valuations are also a concern, prompting investors to seek value opportunities despite numerous uncertainties. The outlook for 2025 is cautiously optimistic, suggesting a potential uptick in market activity and large deals that could foster recovery and momentum. The document emphasizes the importance of seeking professional advice and acknowledges that the information provided is subject to change, urging readers to make informed decisions based on the content presented.
# C:\Users\HP\AppData\Local\Temp\ipykernel_8668\1471321174.py:410: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['date'] = pd.to_datetime(df['date'], errors='coerce', infer_datetime_format=True).dt.strftime('%m/%d/%y')
# Processing complete. Final results saved.

# %%
date_mapping = df2.set_index("title")["date"]
df.loc[df["title"].isin(date_mapping.index), "date"] = df["title"].map(date_mapping)

df.head(16)

df.to_parquet("final_categorized_with_themes_and_summaries.parquet", compression="gzip")
print("Processing complete. Final results saved.")
# Out:
# Processing complete. Final results saved.

# %%
lengths = df['concatenated_text'].apply(len)
average_length = lengths.mean()

print("Average length of 'concatenated_text':", average_length)

lengths = df['normalized_concatenated_text'].apply(len)
average_length = lengths.mean()

print("Average length of 'normalized_concatenated_text':", average_length)

lengths = df['summary'].apply(len)
average_length = lengths.mean()

print("Average length of 'summary':", average_length)
# Out:
# Average length of 'concatenated_text': 66063.35294117648
# Average length of 'normalized_concatenated_text': 48706.117647058825
# Average length of 'summary': 17242.176470588234

# %%
import pandas as pd

df = pd.read_parquet("final_categorized_with_themes_and_summaries.parquet")

# %%
df.head()
# Out:
#           source                                           url_link  \
# 0  KPMG Insights  https://kpmg.com/in/en/insights/2025/02/aau-ac...
# 1  KPMG Insights  https://kpmg.com/in/en/insights/2025/02/food-a...
# 2  KPMG Insights  https://kpmg.com/in/en/insights/2025/02/financ...
# 3  KPMG Insights  https://kpmg.com/in/en/insights/2025/02/kpmg-g...
# 4  KPMG Insights  https://kpmg.com/in/en/insights/2025/02/kpmg-g...
#
#                                                title  \
# 0                      Issue no. 103 | February 2025
# 1             Food and Nutritional Security in India
# 2                           Financial Crime Bulletin
# 3  KPMG global tech report – industrial manufactu...
# 4       KPMG global tech report: Technology insights
#
#                                          description      date  \
# 0  This edition of AAU covers relevant financial ...  02/28/25
# 1  Solutions for achieving zero hunger and ensuri...  02/20/25
# 2  Dive deep into the financial crime avenues and...  02/10/25
# 3  Interoperability, hybrid models and AI innovat...  02/07/25
# 4  Tech: A bold sector that innovates while leadi...  02/07/25
#
#                                              content  \
# 0  Ind AS 103, Business Combination provides guid...
# 1  Food security has been a critical aspect of In...
# 2  Financial crimes have become an ever-evolving ...
# 3  In the rapidly evolving landscape of industria...
# 4  The digital transformation journey is an impor...
#
#                                             pdf_link  \
# 0  https://kpmg.com/content/dam/kpmgsites/in/pdf/...
# 1  https://kpmg.com/content/dam/kpmgsites/in/pdf/...
# 2                                               None
# 3  https://kpmg.com/content/dam/kpmgsites/xx/pdf/...
# 4  https://kpmg.com/content/dam/kpmgsites/xx/pdf/...
#
#                                          pdf_content  \
# 0  February 2025\nkpmg.com/in\nAccounting and \nA...
# 1  Food and nutritional \nsecurity in India\nSolu...
# 2
# 3  KPMG global \ntech report 2024\nKPMG Internati...
# 4  KPMG global \ntech report 2024\nKPMG Internati...
#
#                                    concatenated_text  \
# 0  Ind AS 103, Business Combination provides guid...
# 1  Food security has been a critical aspect of In...
# 2  Financial crimes have become an ever-evolving ...
# 3  In the rapidly evolving landscape of industria...
# 4  The digital transformation journey is an impor...
#
#                                       tokenized_text  \
# 0  ind_as as_103 103_business business_combinatio...
# 1  food_security security_has has_been been_a a_c...
# 2  financial_crimes crimes_have have_become becom...
# 3  in_the the_rapidly rapidly_evolving evolving_l...
# 4  the_digital digital_transformation transformat...
#
#                         normalized_concatenated_text            category  \
# 0  ind 103 business combination provide guidance ...  Economy and Growth
# 1  food security critical aspect indias public po...     India (Country)
# 2  financial crime become everevolving problem me...     Risk Regulation
# 3  rapidly evolve landscape industrial manufactur...          Technology
# 4  digital transformation journey important strat...          Technology
#
#                    niche                                         key_themes  \
# 0       Inflation Trends  [Business Combinations, Sustainability Disclos...
# 1    Agricultural Policy  [Food Security, Public Policy, Nutrition, Sust...
# 2   Financial Compliance  [Financial Crime, Regulatory Initiatives, Tech...
# 3         Industrial IoT  [Digital Transformation, Operational Efficienc...
# 4  Emerging Technologies  [Digital Transformation, Strategic Investment,...
#
#                                     recurring_topics  \
# 0  [IFRS, Measurement Period, Acquisition Method,...
# 1  [Public Distribution System (PDS), Malnutritio...
# 2  [Anti-Money Laundering (AML), Corporate Transp...
# 3  [Industrial Manufacturing, KPMG Global Tech Re...
# 4  [KPMG Global Tech Report, Technology Sector, E...
#
#                                              summary
# 0  The text addresses the guidance provided by IN...
# 1  Food security is a critical aspect of India's ...
# 2  Financial crime is an evolving issue, with an ...
# 3  The KPMG Global Tech Report 2024 highlights th...
# 4  The text emphasizes the importance of digital ...
