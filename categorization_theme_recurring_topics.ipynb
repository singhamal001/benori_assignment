# %% [markdown]
# # Documentation

# %% [markdown]
# ## Overview
# This script processes article data using OpenAI's GPT model to categorize articles, identify niches, extract key themes, and recurring topics. The results are saved in a Parquet file format.
#
# ## Key Functionalities
# 1. **Data Loading:**
#    - Merges data from two Parquet files.
# 2. **Category and Niche Extraction:**
#    - Uses LLM to categorize articles and identify niches based on titles and content.
# 3. **Key Themes and Recurring Topics:**
#    - Extracts broad themes and specific topics from text excerpts.
# 4. **Error Handling:**
#    - Implements retry logic for API calls and checkpoint saving.
#
# ## Dependencies
# - pandas
# - openai
# - tqdm
# - json
# - re
# - os
#
# ## Code Walkthrough
# ### 1. Data Loading
# - Loads and merges Parquet files into a DataFrame.
# - Displays the count of loaded rows.
#
# ### 2. Category and Niche Extraction
# - `process_title`: Sends article titles to LLM for category and niche extraction.
# - `process_text_chunks`: Processes content in chunks if the title is insufficient.
#
# ### 3. Key Themes and Recurring Topics
# - `extract_key_themes_and_recurring_topics`: Extracts themes from the introduction and recurring topics from the entire text.
#
# ### 4. Error Handling
# - Implements retries for API rate limits.
# - Saves checkpoints periodically.
#
# ### 5. Saving Results
# - Saves processed results into a Parquet file.
#
# ## Usage
# Run the script with a valid OpenAI API key set in the environment variables:
# ```
# export OPENAI_API_KEY="your_api_key"
# python script.py
# ```
#
# ## Conclusion
# This script automates the categorization of articles and extraction of insights using OpenAI's API, providing a structured approach to handling large datasets.

# %% [markdown]
# # Code

# %%
import os
import pandas as pd
import json
import re
from tqdm import tqdm
import openai
import time

openai.api_key = os.getenv("OPENAI_API_KEY")

print("Loading data...")
df1 = pd.read_parquet("kpmg_india/kpmg_final_concatenated_insights_gzip.parquet")
df2 = pd.read_parquet("pwc_india/pwc_final_concatenated_insights_gzip.parquet")
df = pd.concat([df1, df2], ignore_index=True)
print(f"Loaded {len(df)} rows after merging")

def save_checkpoint(df, iteration, total):
    checkpoint_file = f"checkpoint_{iteration}_of_{total}.parquet"
    df.to_parquet(checkpoint_file, compression="gzip")
    print(f"Checkpoint saved: {checkpoint_file}")

def extract_json(text):
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        json_pattern = r'({[\s\S]*})'
        json_match = re.search(json_pattern, text)
        if json_match:
            try:
                return json.loads(json_match.group(1))
            except json.JSONDecodeError:
                pass
        category_match = re.search(r'category[:\s]+["\'](.*?)["\']', text, re.IGNORECASE)
        niche_match = re.search(r'niche[:\s]+["\'](.*?)["\']', text, re.IGNORECASE)
        if category_match and niche_match:
            return {"category": category_match.group(1), "niche": niche_match.group(1)}
        return {"category": "", "niche": ""}

def extract_list_from_response(text):
    try:
        data = json.loads(text)
        if isinstance(data, dict) and "items" in data:
            return data["items"]
        elif isinstance(data, list):
            return data
        
        matches = re.findall(r'[\"\']([^\"\']+)[\"\']', text)
        if matches:
            return matches
            
        list_items = re.findall(r'(?:^|\n)[\d\-\*]+\.?\s*([^\n]+)', text)
        if list_items:
            return [item.strip() for item in list_items]
            
    except json.JSONDecodeError:
        pass
    
    if "," in text:
        return [item.strip() for item in text.split(",") if item.strip()]
    else:
        return [item.strip() for item in text.split("\n") if item.strip()]

def invoke_llm(prompt, max_retries=5):
    for attempt in range(max_retries):
        try:
            response = openai.ChatCompletion.create(
                model="gpt-4o-mini",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.0
            )
            return response.choices[0].message['content'].strip()
        except Exception as e:
            if "429" in str(e):
                wait_time = 2 ** attempt
                print(f"Rate limit exceeded. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                print(f"LLM request failed: {e}")
                break
    return ""

def process_title(title):
    prompt = f"""
    Given the following article title:
    "{title}"

    Classify it into one of these categories:
    ["Supply Chain", "Energy Renewables", "Cyber Security", "Economy and Growth", "ESG", "Technology", "Risk Regulation", "Workforce", "Transformation", "India (Country)", "Healthcare"]

    Additionally, identify a relevant **niche** within this category.
    The **category must be from the list**, but the **niche can be any relevant term**.

    Return ONLY a JSON object with 2 keys: "category" and "niche".
    Example: {{"category": "Technology", "niche": "Cloud Computing"}}
    
    Do not include ANY explanatory text before or after the JSON.
    """
    response = invoke_llm(prompt)
    return extract_json(response)

def process_text_chunks(text):
    chunk_size = 400
    words = text.split()
    num_chunks = min(2, len(words) // chunk_size + (1 if len(words) % chunk_size > 0 else 0))

    category_votes = []
    niche_votes = []

    for i in range(num_chunks):
        chunk = " ".join(words[i * chunk_size:(i + 1) * chunk_size])
        prompt = f"""
        Given the following article excerpt:
        "{chunk}"

        Classify it into one of these categories:
        ["Supply Chain", "Energy Renewables", "Cyber Security", "Economy and Growth", "ESG", "Technology", "Risk Regulation", "Workforce", "Transformation", "India (Country)", "Healthcare"]

        Additionally, identify a relevant **niche** within this category.
        The **category must be from the list**, but the **niche can be any relevant term**.

        Return ONLY a JSON object with 2 keys: "category" and "niche".
        Example: {{"category": "Technology", "niche": "Cloud Computing"}}
        
        Do not include ANY explanatory text before or after the JSON.
        """
        response = invoke_llm(prompt)
        result = extract_json(response)
        category_votes.append(result.get("category", ""))
        niche_votes.append(result.get("niche", ""))

    final_category = max(set(category_votes), key=category_votes.count) if category_votes else ""
    final_niche = max(set(niche_votes), key=niche_votes.count) if niche_votes else ""

    return {"category": final_category, "niche": final_niche}

def extract_key_themes_and_recurring_topics(text):
    """
    Extracts key themes from the introduction (first 1/3rd of the text) and 
    recurring topics from the remaining text, processing the text in chunks.
    
    For the introduction portion, a combined prompt extracts both key themes and recurring topics.
    For the remaining text, we process in chunks to extract recurring topics.
    
    Returns:
        tuple: (list of key themes, list of recurring topics)
    """
    if pd.isna(text) or text == "":
        return [], []
    
    total_length = len(text)
    intro_threshold = total_length // 3
    chunk_size = 3000
    key_themes = []
    recurring_topics = []

    for i in range(0, intro_threshold, chunk_size):
        chunk = text[i:i+chunk_size]
        prompt_intro = f'''
        Given the following text excerpt from an article:
        "{chunk}"
        
        Identify the most important key themes addressed in this text.
        Key themes should be broad concepts or subjects that form the foundation of the content.
        
        Additionally, identify specific recurring topics that are mentioned or discussed multiple times in this excerpt.
        Recurring topics should be specific subjects, terms, or concepts that appear repeatedly.
        
        Return ONLY a JSON object with two keys: "key_themes" and "recurring_topics".
        Example: {{"key_themes": ["Digital Transformation", "Regulatory Compliance", "Risk Management"],
        "recurring_topics": ["Supply Chain Disruption", "Blockchain Implementation", "Vendor Management", "Cost Optimization"]}}
        
        Be concise and specific. Each key theme should be 1-3 words when possible, and each recurring topic 2-4 words.
        Do not include ANY explanatory text before or after the JSON.
        '''
        response_intro = invoke_llm(prompt_intro)
        result = extract_json(response_intro)
        
        if "key_themes" in result:
            new_key_themes = result.get("key_themes", [])
            for theme in new_key_themes:
                cleaned_theme = theme.strip()
                if cleaned_theme and cleaned_theme.lower() not in [t.lower() for t in key_themes]:
                    key_themes.append(cleaned_theme)
        else:
            new_key_themes = extract_list_from_response(response_intro)
            for theme in new_key_themes:
                cleaned_theme = theme.strip()
                if cleaned_theme and cleaned_theme.lower() not in [t.lower() for t in key_themes]:
                    key_themes.append(cleaned_theme)
        
        if "recurring_topics" in result:
            new_topics = result.get("recurring_topics", [])
            recurring_topics.extend(new_topics)
    
    for j in range(intro_threshold, total_length, chunk_size):
        chunk = text[j:j+chunk_size]
        prompt_remaining = f'''
        Given the following text excerpt from an article:
        "{chunk}"
        
        Identify the recurring topics that are mentioned or discussed multiple times.
        Recurring topics should be specific subjects, terms, or concepts that appear repeatedly.
        
        Return ONLY a JSON object with a single key "items" containing an array of topics.
        Example: {{"items": ["Supply Chain Disruption", "Blockchain Implementation", "Vendor Management", "Cost Optimization"]}}
        
        Be specific and detailed. Each topic can be 2-4 words.
        Do not include ANY explanatory text before or after the JSON.
        '''
        response_remaining = invoke_llm(prompt_remaining)
        remaining_topics = extract_list_from_response(response_remaining)
        recurring_topics.extend(remaining_topics)
    
    unique_recurring_topics = []
    lower_topics = set()
    for topic in recurring_topics:
        cleaned_topic = topic.strip()
        if cleaned_topic and cleaned_topic.lower() not in lower_topics:
            unique_recurring_topics.append(cleaned_topic)
            lower_topics.add(cleaned_topic.lower())
    
    return key_themes, unique_recurring_topics

def main():
    if "category" not in df.columns:
        df["category"] = None
    if "niche" not in df.columns:
        df["niche"] = None
    if "key_themes" not in df.columns:
        df["key_themes"] = None
    if "recurring_topics" not in df.columns:
        df["recurring_topics"] = None
    
    total_rows = len(df)
    checkpoint_interval = 50
    
    try:
        for i in tqdm(range(total_rows)):
            title = df.at[i, "title"]
            text = df.at[i, "normalized_concatenated_text"] if "normalized_concatenated_text" in df.columns else ""
            
            if (pd.notna(df.at[i, "category"]) and 
                pd.notna(df.at[i, "niche"]) and 
                pd.notna(df.at[i, "key_themes"]) and 
                pd.notna(df.at[i, "recurring_topics"])):
                continue
                
            if pd.isna(title) or title == "":
                df.at[i, "category"] = ""
                df.at[i, "niche"] = ""
                df.at[i, "key_themes"] = []
                df.at[i, "recurring_topics"] = []
                continue
            
            if pd.isna(df.at[i, "category"]) or pd.isna(df.at[i, "niche"]):
                title_result = process_title(title)
                text_result = process_text_chunks(text) if text else {"category": "", "niche": ""}
                final_category = title_result["category"] if title_result["category"] else text_result["category"]
                final_niche = title_result["niche"] if title_result["niche"] else text_result["niche"]
                df.at[i, "category"] = final_category
                df.at[i, "niche"] = final_niche
                print(f"Row {i}: {title} → Category: {final_category}, Niche: {final_niche}")
            
            if pd.isna(df.at[i, "key_themes"]) or pd.isna(df.at[i, "recurring_topics"]):
                key_themes, recurring_topics = extract_key_themes_and_recurring_topics(text)
                df.at[i, "key_themes"] = key_themes
                df.at[i, "recurring_topics"] = recurring_topics
                print(f"Row {i}: Key Themes: {key_themes}")
                print(f"Row {i}: Recurring Topics: {recurring_topics}")
            
            if (i + 1) % checkpoint_interval == 0:
                save_checkpoint(df, i + 1, total_rows)
        df['date'] = pd.to_datetime(df['date'], errors='coerce', infer_datetime_format=True).dt.strftime('%m/%d/%y')
        df.to_parquet("final_categorized_with_themes.parquet", compression="gzip")
        print("Processing complete. Final results saved.")
    except Exception as e:
        print(f"Error during processing: {e}")
        save_checkpoint(df, "error", total_rows)
        print("Progress saved before error.")
        raise e

if __name__ == "__main__":
    main()
# Out:
# Loading data...
# Loaded 17 rows after merging
#   0%|          | 0/17 [00:00<?, ?it/s]
# Row 0: Issue no. 103 | February 2025 → Category: Economy and Growth, Niche: Inflation Trends
#   6%|▌         | 1/17 [00:33<08:51, 33.19s/it]
# Row 0: Key Themes: ['Business Combination', 'Sustainability Disclosure', 'Regulatory Updates', 'Regulatory Compliance', 'Measurement Period', 'Provisional Amount', 'Accounting Standards', 'Business Combinations', 'Financial Reporting', 'Fair Value Accounting', 'Sustainability Reporting', 'Material Information', 'Financial Disclosure', 'Materiality Judgement']
# Row 0: Recurring Topics: ['Acquisition Method', 'Measurement Period', 'Provisional Amount', 'Material Information', 'Sustainability-related Risk', 'Risk Opportunity', 'Audit Committee Approval', 'Accounting Guidance', 'Acquisition Date', 'Adjustment Provisional Amount', 'Information Obtain', 'Goodwill Measurement', 'Asset Valuation', 'Financial Statement', 'Depreciation Expense', 'Goodwill Adjustment', 'Provisional Fair Value', 'Financial Statement Disclosure', 'Disclosure Requirements', 'IFRS Standards', 'Materiality Judgement', 'Primary User Decision', 'Sustainability-related Financial Disclosure', 'Information Need', 'Potential Investor', 'Entity Circumstance', 'Financial Report', 'Assessment Process', 'Identifying Material Information', 'disclosure requirement', 'primary user', 'education material', 'potentially material information', 'decision-making', 'climate-related information', 'Quantitative Factor', 'Qualitative Factor', 'Entity-specific External Factor', 'Cash Flow Impact', 'Resource Consumption', 'Investment Return', 'Market Share', 'Governance Interaction', 'Stakeholder Relationship', 'Business Model Strategy', 'Geographical Location', 'Economic State', 'Possible Future Event', 'Likelihood of Outcome', 'Judgement Exercise', 'Aggregate Information', 'Disaggregate Information', 'Change Circumstance', 'Opportunity Disclosure', 'General-purpose Financial Report', 'Review Draft', 'Assessment of materiality', 'Regulatory compliance', 'Secretarial compliance report', 'Public feedback', 'Audit update', 'KPMG assurance consulting', 'Entity reporting requirements', 'Financial statement relation', 'Secretarial Audit', 'Compliance Report', 'Statutory Auditor', 'Related Party Transactions', 'Monetary Threshold', 'Subsidiary Definition', 'Financial Track Record', 'Material Event Disclosure', 'SEBI Amendments', 'Industry Standard Recognition', 'KPMG Assurance', 'Material RPTs', 'Implementation Standards', 'Regulated Entities', 'Standard Operating Procedure', 'Audit Committee', 'ESG Rating', 'Compliance Deadline', 'Dematerialisation of Securities', 'Quality Review Board', 'Profit and Loss', 'Corporate Affairs', 'Industry Standards', 'Quality Control', 'Audit Report', 'Noncompliance Guidance', 'Settlement Procedure', 'Asset Reconstruction Company', 'Nonperforming Assets', 'Reserve Bank of India', 'Independent Advisory Committee', 'Settlement Policy', 'Housing Finance Companies', 'Nonconvertible Debentures', 'Private Placement', 'Regulatory Framework', 'Insurance Sector', 'Data Governance', 'Operational Efficiency', 'Artificial Intelligence', 'Machine Learning', 'Financial Companies', 'Regulatory Sandbox', 'AI ML Tools', 'Investment Opportunities', 'Water Pollution Control', 'Air Pollution Control', 'AIF Regulation', 'SEBI Guidelines', 'Investor Stakeholder Data', 'IFRS S1', 'IFRS S2', 'Climate-related Disclosure', 'Sustainability Reporting', 'Transition Relief', 'Sustainability-related Risks', 'Business Responsibility Sustainability Report', 'ESG Disclosures', 'KPMG Guidance', 'BRSR Facilitation', 'SEBI Circular', 'Industry Standard Report', 'Core Standard Implementation', 'Financial Report Update', 'Regulatory Update', 'Quarterly Publication', 'Environmental Ministry']
# Row 1: Food and Nutritional Security in India → Category: India (Country), Niche: Agricultural Policy
#  12%|█▏        | 2/17 [00:48<05:43, 22.90s/it]
# Row 1: Key Themes: ['Food Security', 'Public Policy', 'Sustainable Agriculture', 'Nutritional Security', 'Multistakeholder Approach', 'Nutrition Education', 'School Meal Programs']
# Row 1: Recurring Topics: ['Public Distribution System', 'Nutritional Programs', 'Digital Reform', 'Malnutrition', 'Food Waste', 'Smallholder Farmers', 'Undernutrition', 'Child Development', 'Food Distribution', 'School Feeding Program', 'Agricultural Sustainability', 'Fortified Milk', 'Midday Meal Scheme', 'Micronutrient Deficiency', 'Local Agriculture', 'Child Nutrition', 'Anaemia Prevention', 'School Meal Programs', 'Nutritional Education', 'Fortified Milk Initiatives', 'Local Agriculture Promotion', 'Community Gardens', 'Regional Meal Plans', 'Technology in Nutrition Tracking', 'Food Subsidy Program', 'Nutritional Status', 'Digitalization and Technology', 'Food Grain Management', 'Access to Nutritious Food', 'Rural and Urban Households', 'Aadhaar-based Authentication', 'Leakage and Waste', 'Smart Ration Card', 'Inventory and Storage', 'Transportation Challenges', 'Government Schemes', 'Nutritional Counseling', 'Food Security Act', 'One Nation One Ration Card', 'Fair Price Shop', 'Food Security', 'Migrant Worker Support', 'Food Grain Distribution', 'Economic Disruption', 'Technology Infrastructure', 'Biometric Authentication', 'Home Delivery Services', 'Agricultural Import Dependency', 'Food Production Targets', 'Pulse Production', 'Agricultural Practices', 'Price Support Scheme', 'Market Price Monitoring', 'Climate Change Mitigation', 'Sustainable Agriculture', 'Nutritional Security', 'Community Participation', 'High Yield Variety Seeds', 'Crop Insurance', 'Government Initiatives', 'Minimum Support Price', 'Food Import Dependency', 'public service', 'head government', 'head client market', 'nilachal mishra', 'akhilesh tuteja']
# Row 2: Financial Crime Bulletin → Category: Risk Regulation, Niche: Anti-Money Laundering
#  18%|█▊        | 3/17 [00:54<03:28, 14.86s/it]
# Row 2: Key Themes: ['Financial Crime', 'Regulatory Initiatives', 'Risk Management']
# Row 2: Recurring Topics: ['Anti-Money Laundering', 'Fraud Detection', 'Beneficial Ownership', 'Corporate Transparency', 'Technological Integration', 'Compliance Requirements', 'Corporate White-Collar Crime', 'AML Compliance', 'Fraud Risk Management', 'Financial Crime Prevention', 'Internal Risk Assessment', 'Digital Payment Advancements', 'Surveillance Systems', 'Whistleblower Policies', 'Technology in Financial Crime', 'Regulatory Changes']
# Row 3: KPMG global tech report – industrial manufacturing insights → Category: Technology, Niche: Industrial IoT
#  24%|██▎       | 4/17 [01:30<05:03, 23.37s/it]
# Row 3: Key Themes: ['Digital Transformation', 'Operational Efficiency', 'AI Adoption', 'Technology Innovation', 'Value Creation', 'Risk Management', 'Investment Strategy', 'Technology Adoption', 'Technology Investment', 'Strategic Implementation', 'Data Analytics', 'Profitability', 'Leadership Strategy']
# Row 3: Recurring Topics: ['Industrial Manufacturing', 'Data Strategy', 'Cybersecurity Measures', 'Technology Leadership', 'Generative AI', 'Quantum Computing', 'Evidence-Based Decision', 'Technology Investment', 'Senior Leadership', 'High Performers', 'Fear of Missing Out', 'Executive Decision Making', 'Customer Feedback', 'Competitor Influence', 'XaaS Technology', 'Cloud Computing', 'Cybersecurity', 'AI Automation', 'Cost Reduction', 'Employee Feedback', 'Tech Adoption', 'Tech Debt', 'Data Analytics', 'Executive Satisfaction', 'Value Evaluation', 'Adaptive Approach', 'Executive Decision-Making', 'Partnership Ecosystem', 'Tech Investment Evaluation', 'Sustainability Initiatives', 'Data Maturity', 'Data-Driven Decision Making', 'Customer Experience Improvement', 'AI Solutions', 'Data Accessibility', 'Data Governance', 'Social Responsibility', 'Financial ROI', 'Tech Investment', 'Value Measurement', 'Proficiency Enhancement', 'Business Growth', 'Process Efficiency', 'Predictive Modeling', 'Cost Optimization', 'Digital Transformation', 'Performance Management', 'Cost Forecasting', 'Stakeholder Alignment', 'Data Security Governance', 'Value Tracking Metrics', 'Risk Assessment', 'Evidence-Based Decision Making', 'Organizational Strategy', 'Cybersecurity Metrics', 'Data Security', 'Data Culture', 'Data Interoperability', 'Investment in Data', 'Trust and Security', 'AI and Technology', 'Customer Experience', 'Risk Management', 'Cybersecurity Resilience', 'Data Integrity', 'Employee Training', 'Data Ownership Framework', 'Incident Response', 'Automation Strategy', 'Secure Digital Transformation', 'Business Continuity', 'AI Investment', 'Employee Wellbeing', 'Decision-Making Centralization', 'Communication Breakdown', 'Productivity Improvement', 'Automation Efforts', 'AI Adoption', 'Workforce Anxiety', 'Ethical Concerns', 'Employee Empowerment', 'Strategic Leadership', 'AI Use Cases', 'Return on Investment', 'Maturity Level', 'Tech Landscape Evolution', 'Trust in AI', 'AI Experimentation', 'Decentralized Approach', 'Centralized Control', 'Workforce Collaboration', 'Operational Efficiency', 'Data Infrastructure', 'Business Value Alignment', 'Innovation Democratization', 'Employee Involvement', 'AI Governance', 'Data Quality', 'Risk Mitigation', 'Enterprise Alignment', 'AI Transformation', 'Ethical Use of AI', 'Interoperability', 'Value Optimization', 'Collaboration Across Teams', 'AI Integration', 'Skill Gap', 'Predictive Analytics', 'High-Performing Organizations', 'Workforce Contribution', 'Innovation Centers of Excellence', 'Tech Performance Measurement', 'Sustainable Value', 'Market Share Growth', 'AI Value Optimization', 'Data Management Framework', 'Technical Debt Management', 'Stakeholder Trust', 'Cross-Functional Collaboration', 'Customer-Centric Transformation', 'Performance Management Metrics', 'Ethical AI Use', 'Innovation and Technology', 'Business Transformation', 'Technological Innovation', 'AI Confidence', 'Global Delivery Network', 'Service Management', 'KPMG International']
# Row 4: KPMG global tech report: Technology insights → Category: Technology, Niche: Emerging Technologies
#  29%|██▉       | 5/17 [01:59<05:03, 25.30s/it]
# Row 4: Key Themes: ['Digital Transformation', 'Technology Strategy', 'Investment Discipline', 'AI Implementation', 'Value Optimization', 'Technology Investment', 'Competitive Advantage', 'Technology Adoption', 'Profitability Improvement', 'Technical Debt']
# Row 4: Recurring Topics: ['AI and ESG', 'Risk Management', 'Evidence-Based Decisions', 'Technology Innovation', 'KPMG Global Tech Report', 'Evidence-Based Decision', 'Senior Leadership Insight', 'Tech Maturity Stage', 'FOMO', 'Third-party Guidance', 'In-house Trials', 'Customer Feedback', 'Senior Leadership', 'Cost Effectiveness', 'XaaS Technology', 'AI Automation', 'Data Analytics', 'Cybersecurity', 'Cloud Computing', 'Strategic Vision', 'Executive Buy-in', 'High Performers', 'Legacy Systems', 'New Technology', 'Tech Debt', 'Investment Strategy', 'Ecosystem Partnerships', 'Sustainability', 'Data maturity', 'Tech initiative', 'Long-term goals', 'Tech Investment', 'Data-Driven Decision', 'Social Responsibility', 'Data Accessibility', 'Data Governance', 'AI Confidence', 'Data Interoperability', 'Data Culture', 'Data Security', 'Cloud Platform', 'Customer Feedback Utilization', 'Data Management Integration', 'Technology Investment Strategy', 'Service Pain Points', 'Smart Contracts', 'Blockchain Tokenization', 'Performance Metrics', 'Cost Forecasting', 'Digital Transformation', 'Value Tracking Metrics', 'Proactive Decision-Making', 'Growth Opportunities', 'Organizational Efficiency', 'Investment Portfolio Alignment', 'Stakeholder Consensus', 'Performance Management', 'Data Security Governance', 'Cybersecurity Metrics', 'Data Proficiency', 'Evidence-Based Decision Making', 'Data Management Focus', 'High-Performing Organizations', 'Customer Trust', 'Trust and Security', 'Data-Centric Culture', 'Operational Control', 'Employee Training', 'Incident Response', 'Technology Investment', 'Business Continuity', 'Data Integrity', 'Value Creation', 'AI Adoption', 'Executive Decision-Making', 'Data Ownership', 'Market Risk', 'Workforce Anxiety', 'Governance Bottleneck', 'Decision-Making Centralization', 'Employee Empowerment', 'Creative Thinking', 'Operational Structure', 'Productivity Improvement', 'Ethical Concerns', 'Tech Leadership Evolution', 'Communication Breakdown', 'Job Redefinition', 'Market Response', 'AI Use Cases', 'Organizational Strategy', 'Value Generation', 'Ethical AI', 'Workforce Engagement', 'Decentralized Innovation', 'AI Experimentation', 'Centralized Approach', 'Democratized Experimentation', 'Cross-Functional Collaboration', 'Data Infrastructure', 'Operational Efficiency', 'Risk Mitigation', 'AI Investment', 'Customer Engagement', 'Data Quality', 'Innovation', 'Portfolio Approach', 'Return on Investment', 'AI Governance', 'Value Optimization', 'AI Transformation', 'Business Strategy', 'Skill Gap', 'Predictive Analytics', 'Interoperability', 'Ethical AI Use', 'AI Expertise', 'Data Management', 'Business Value', 'Predictive Data Insight', 'High-Performing Organization', 'Customer Experience', 'Enterprise Mindset', 'ROI', 'Strategic Objectives', 'Value Delivery', 'Stakeholder Alignment', 'Technical Debt Management', 'Data Management Framework', 'AI Proficiencies', 'Innovation Collaboration', 'Artificial Intelligence', 'Resilient Solutions', 'Client Services', 'Professional Advice', 'Global Organization', 'Member Firm', 'Copyright Information']
# Row 5: KPMG global tech report: energy insights → Category: Energy Renewables, Niche: Sustainable Energy Solutions
#  35%|███▌      | 6/17 [02:35<05:17, 28.90s/it]
# Row 5: Key Themes: ['Energy Transformation', 'Technological Innovation', 'Strategic Decision-Making', 'Technology Leadership', 'Digital Transformation', 'AI Implementation', 'AI Investment', 'Market Competition', 'Technology Adoption', 'Strategic Investment', 'Technology Investment', 'Profitability', 'Decision Making']
# Row 5: Recurring Topics: ['AI and Advanced Analytics', 'Evidence-Based Decisions', 'Renewable Integration', 'Cybersecurity Threats', 'KPMG Global Tech Report', 'Evidence-Based Decision Making', 'Senior Leadership Insights', 'Industry-Specific Challenges', 'Fear of Missing Out', 'Third-Party Guidance', 'In-House Trials', 'Customer Feedback', 'Technology Adoption', 'XaaS Technology', 'Cloud Computing', 'Data Analytics', 'AI Automation', 'Cybersecurity', 'Cost Reduction', 'Executive Buy-in', 'Tech Debt', 'Business Value', 'High Performers', 'New Technology', 'Existing Technology', 'Executive Intentions', 'Ecosystem Partnership', 'Evidence-Based Decision', 'Sustainability', 'Customer Experience', 'Data Maturity', 'Tech Investment', 'Data-Driven Decision', 'Social Responsibility', 'Data Management', 'AI Solutions', 'Value Measurement', 'Digital Transformation', 'Performance Monitoring', 'Cost Forecasting', 'Proactive Decision-Making', 'Growth Opportunities', 'Risk Mitigation', 'Long-term goals', 'Tech investment portfolio', 'Data security governance', 'Value-driven decision', 'Performance management', 'Stakeholder alignment', 'Cybersecurity metrics', 'Data proficiency', 'Cybersecurity Risk', 'Data Interoperability', 'Trust and Security', 'Data Accessibility', 'Data-Driven Decision Making', 'Cybersecurity Training', 'Tech Investment Risk', 'Enterprise Data Strategy', 'Cybersecurity Resilience', 'Data Security', 'Incident Response', 'Data Hygiene Audit', 'Employee Empowerment', 'Automation Strategy', 'Risk Management', 'Value Optimization', 'Tech Innovation', 'Risk Aversion', 'AI Adoption', 'Market Response', 'Governance Bottleneck', 'Productivity Improvement', 'Operational Structure', 'Creative Roles', 'Decision-Making Centralization', 'Tech Executive Roles', 'Strategic Leadership', 'Ethical AI', 'Value Generation', 'AI Use Cases', 'Organizational Maturity', 'Decentralized Innovation', 'Workforce Experimentation', 'AI Experimentation', 'Centralized Approach', 'Democratized Experimentation', 'Cross-Functional Collaboration', 'AI Center of Excellence', 'Operational Efficiency', 'Innovation', 'Data Infrastructure', 'Employee Involvement', 'Use Case Development', 'Portfolio Approach', 'Return on Investment', 'AI Governance', 'Data Quality', 'AI Transformation', 'Interoperability', 'Business Strategy', 'Ethical AI Use', 'Stakeholder Communication', 'AI Capability', 'Budget Allocation', 'AI Performance Analysis', 'Predictive Analytics', 'Skill Gap', 'High-Performing Organizations', 'Technology Investment', 'Market Share Growth', 'Data Management Framework', 'Technical Debt Management', 'AI Proficiencies', 'Stakeholder Trust', 'Innovation and Technology', 'Empirical Decision Making', 'Collaboration and Partnership', 'Cybersecurity Concerns', 'Customer-Centric Transformation', 'Technology Solutions', 'Artificial Intelligence', 'Cloud Technology', 'Strategic Partnerships', 'KPMG International', 'Global Technology Report']
# Row 6: KPMG global tech report 2024 → Category: Technology, Niche: Emerging Technologies
#  41%|████      | 7/17 [03:06<04:55, 29.58s/it]
# Row 6: Key Themes: ['Tech Innovation', 'Strategic Decision-Making', 'Value Creation', 'Digital Transformation', 'AI Implementation', 'Business Strategy', 'Technology Investment', 'Competitive Advantage', 'Technology Adoption', 'Profitability Improvement', 'Tech Debt', 'Value Optimization', 'Sustainability']
# Row 6: Recurring Topics: ['Evidence-Based Decisions', 'Technology Leadership', 'Risk Management', 'AI Implementation', 'Business Transformation', 'Value Optimization', 'Evidence-Based Decision', 'Senior Leadership Insight', 'Tech Initiative Measurement', 'Fear of Missing Out', 'Third-Party Guidance', 'In-House Trials', 'Customer Feedback', 'Competitor Analysis', 'XaaS Technology', 'Cloud Computing', 'AI Automation', 'Data Analytics', 'Cybersecurity', 'Strategic Vision', 'Investment Priorities', 'Profitability Boost', 'Legacy Systems', 'XaaS Investment', 'High Performers', 'Tech Initiative', 'Business Value Outcomes', 'Tech Investment Portfolio', 'Long-Term Goals', 'Customer Experience', 'Data Maturity', 'Tech Investment', 'Data-Driven Decision', 'Sustainability', 'Social Responsibility', 'Data Management', 'Data Accessibility', 'Data Governance', 'Data Culture', 'AI Confidence', 'Business Strategy', 'Data Proficiency', 'Digital Transformation', 'Cost Forecasting', 'Value Creation', 'Performance Metrics', 'Process Efficiency', 'Risk Mitigation', 'Decision-Making', 'Longterm Strategic Goals', 'Stakeholder Alignment', 'Performance Management', 'Data Security Governance', 'Cybersecurity Metrics', 'Evidence-Based Decision Making', 'Data Monetization', 'Data Interoperability', 'Data Security', 'Trust and Security', 'Data-Centric Culture', 'Operational Control', 'Employee Training', 'Technology Investment', 'Resilience and Trust', 'Business Continuity Plan', 'Incident Response', 'Data Hygiene Audit', 'Digital Transformation Strategy', 'AI Adoption', 'Executive Decision-Making', 'Employee Empowerment', 'Market Response', 'Product Offering', 'Governance Challenges', 'Communication Breakdown', 'Workforce Anxiety', 'Creative Roles', 'Operational Structure', 'Decision-Making Centralization', 'Automation Efforts', 'Employee Wellbeing', 'Technology Evolution', 'Tech Workforce', 'Strategic Innovation', 'Ethical AI', 'Value Generation', 'Decentralized Approach', 'Experimentation', 'Business Capability', 'Productivity Improvement', 'AI Use Cases', 'Maturity Level', 'Collaboration', 'Cost Sensitivity', 'AI Experimentation', 'Centralized Approach', 'Democratized Experimentation', 'Cross-Functional Collaboration', 'Operational Efficiency', 'Data Infrastructure', 'Innovation Mitigation', 'Return on Investment', 'Customer Engagement', 'Human-AI Collaboration', 'Portfolio Approach', 'Production-Level Practices', 'Technical Debt', 'Data Flow Sovereignty', 'Access Control', 'AI Governance', 'Generative AI Risks', 'AI Transformation', 'Business Strategy Alignment', 'Data Quality Integrity', 'AI Capability Development', 'Interoperability', 'Performance Measurement', 'Ethical AI Use', 'Stakeholder Communication', 'Budget Allocation', 'Trust in AI', 'AI Adoption Roadmap', 'High-Performing Organizations', 'Employee Contribution', 'Innovation Consolidation', 'Value Delivery', 'AI Proficiencies', 'Technical Debt Management', 'Stakeholder Trust', 'Empirical Decision Making', 'Collaboration and Innovation', 'Security Assurance', 'KPMG International', 'Global Technology Report', 'AI Solutions', 'Partnerships and Alliances', 'Expanded Product Offering', 'Client Services', 'Resilient Solutions', 'Professional Advice', 'Technology Consulting']
# Row 7: Quality measures and standards for transitioning to value-based healthcare in India → Category: Healthcare, Niche: Value-Based Care
#  47%|████▋     | 8/17 [03:53<05:17, 35.29s/it]
# Row 7: Key Themes: ['Value-Based Healthcare', 'Quality Measurement', 'Healthcare Transformation', 'Healthcare Accessibility', 'Technological Innovation', 'Patient Experience', 'Healthcare Infrastructure', 'Value-Based Care', 'Healthcare Innovation', 'Patient Outcomes', 'Healthcare Spending', 'Quality Metrics', 'Payment Models', 'Quality Improvement', 'Healthcare Costs', 'Cost Optimization', 'Healthcare Access', 'Chronic Disease Management']
# Row 7: Recurring Topics: ['Patient Outcomes', 'Cost Efficiency', 'Healthcare Delivery', 'Chronic Disease Management', 'Healthcare Access', 'Patient Satisfaction', 'Quality Healthcare', 'Healthcare Costs', 'Telemedicine', 'Healthcare Providers', 'Government Initiatives', 'Integrated Care Delivery', 'Outcome-Based Payment', 'Patient-Centered Care', 'Healthcare Provider', 'Cost Reduction', 'Quality Care', 'Patient Safety', 'Digital Innovation', 'Monitoring Mechanism', 'Hospital Readmission Reduction', 'Preventive Care', 'Integrated Care Systems', 'Cost Effectiveness', 'Patient Experience', 'Clinical Outcomes', 'Payment Models', 'Healthcare Standards', 'Knee Replacement Surgery', 'Risk Sharing Agreement', 'Clinical Team Awareness', 'Capitation Model', 'Data Extraction Challenges', 'Health Outcomes', 'Insurance Coverage', 'Out-of-Pocket Expenses', 'Electronic Medical Record', 'Data Analytics Capability', 'Socioeconomic Stratum', 'Healthcare System Transformation', 'Financial Protection', 'Patient Engagement', 'Quality Healthcare Service', 'Value-Based Healthcare', 'Healthcare System Improvement', 'Quality Healthcare Services', 'Healthcare Transformation', 'National Health Stack', 'Digital Health Ecosystem', 'Comprehensive Care', 'Health Equity', 'Value-Based Care', 'Healthcare Provider Performance', 'Quality Assurance', 'Digital Health Infrastructure', 'Financial Incentives', 'Public-Private Partnership', 'Maternal and Child Health', 'Chronic Care Program', 'Healthcare Cost Reduction', 'Quality Measure', 'Patient Health Outcome', 'Adherence Clinical Guideline', 'Patient Safety Indicator', 'Healthcare Spending', 'Cost per Outcome', 'Readmission Rate', 'Care Transition', 'Symptom Management', 'Healthcare Cost', 'Clinical Measure', 'Pain Management Protocols', 'Patient Care Quality', 'Health Technology Assessment', 'Key Performance Indicators', 'Healthcare Accessibility', 'Cost Measures', 'Health Financing', 'Healthcare Coordination', 'Treatment Cost', 'Payment Model Transformation', 'Infection Control', 'Healthcare Quality Standards', 'Patient Wellbeing', 'Preventable Mortality', 'Adverse Events', 'Cleanliness Monitoring', 'Healthcare Provider Incentives', 'Patient Feedback', 'Nosocomial Infections', 'Medication Safety', 'Environmental Audits', 'Surgical Site Infections', 'Healthcare Cost Control', 'Quality Metrics', 'Healthcare Provider Communication', 'Reimbursement Models', 'Care Coordination', 'Performance Evaluation', 'Audit Review', 'Real-Time Alerts', 'Care Efficiency', 'Patient Outcome', 'Quality Indicator', 'Length of Stay', 'Digital Integration', 'Hospital-Acquired Infection', 'Clinical Care Efficiency', 'Cost Implication', 'Prescription Audit', 'Avoidable Pathology', 'Readmission Rates', 'Diagnostic Tests', 'Resource Management', 'Technology Integration', 'Mortality Rate', 'Data Sharing', 'Telehealth Platform', 'Patient Monitoring', 'Risk Sharing', 'Quality Measures', 'Analytics Tools', 'Operational Workflow', 'Healthcare Delivery Performance', 'Healthcare Data Management', 'Clinical Decision Support', 'Telemedicine Access', 'Data Analytics Tools', 'Financial Performance Management', 'Remote Healthcare Access', 'Data Integration Platform', 'Electronic Health Records', 'Patient Generated Data', 'Healthcare Interoperability', 'Data Analytics', 'Patient Outcome Improvement', 'Operational Efficiency', 'Data Governance', 'Healthcare Data Architecture', 'Health Outcome Metrics', 'Quality Care Metrics', 'Remote Healthcare Services', 'Data Acquisition', 'Cloud-Based Data Lakes', 'Data Anonymization', 'Enterprise Data Lake', 'Healthcare Analytics', 'Patient Privacy', 'Data Standardization', 'Healthcare Cost Reimbursement', 'EMR System Maturity', 'Stakeholder Engagement', 'Quality Outcome Data', 'Baseline Data', 'Cost-Benefit Analysis', 'Digital Health Standards', 'Performance Data', 'Investment in Quality Care', 'Resistance to Data Publication', 'Patient Care Provision', 'Benchmarking Outcomes', 'Healthcare Provider Accreditation', ...
# Row 8: The mutual funds route to Viksit Bharat @2047 → Category: Economy and Growth, Niche: Investment Strategies
#  53%|█████▎    | 9/17 [04:47<05:27, 41.00s/it]
# Row 8: Key Themes: ['Financial Inclusion', 'Investor Empowerment', 'Mutual Fund Industry', 'Mutual Fund Growth', 'Investment Culture', 'Financial Empowerment', 'Digital Transformation', 'Investment Growth', 'Cultural Integration', 'Investor Education', 'Technology Integration', 'Community Engagement', 'Cultural Alignment', 'Economic Transformation', 'Investment Choices', 'Mutual Funds', 'Financial Sector Development', 'Regulatory Framework', 'Market Expansion', 'Market Participation', 'Investor Awareness', 'Market Volatility', 'Mutual Fund Adoption', 'Financial Education', 'Investment Accessibility', 'Digital Platforms', 'Financial Planning', 'Regulatory Compliance', 'Cost Efficiency', 'ESG Integration', 'Investor Protection']
# Row 8: Recurring Topics: ['Democratization of Wealth', 'Financial Literacy', 'Technological Integration', 'Trust Building', 'Investment Accessibility', 'Asset Management', 'Retail Mutual Fund', 'Systematic Investment Plan', 'Investor Confidence', 'Financial Wellbeing', 'Mutual Fund Industry', 'Investor Flexibility', 'Financial Inclusion', 'Asset Disclosure', 'SIP Inflow', 'Community Engagement', 'Investment Journey', 'Local Leadership', 'Accessible Platform', 'Behavioral Transformation', 'Household Savings', 'Economic Reform', 'Investment Options', 'Regulatory Oversight', 'Market Access', 'Inflation Impact', 'Public Sector Entry', 'Asset Management Companies', 'Investor Participation', 'Cost Reduction', 'Scheme Diversity', 'Retail Participation', 'Regulatory Reform', 'Product Innovation', 'Investment Avenues', 'Casual Investor', 'Distribution Deficit', 'Investment Risk', 'Public Provident Fund', 'Equity Market', 'Mutual Fund', 'Investor Education', 'Technology Integration', 'Tier 2 and Tier 3 Cities', 'RTAs', 'Investor Awareness', 'SIP Investment', 'Distribution Network', 'Debt Funds', 'Regulatory Intervention', 'Sustainable Investment', 'Product Categorization', 'Digital Tools', 'Investor Protection', 'Customer Awareness', 'Economic Growth', 'Financial Empowerment', 'Access to Finance', 'Emergency Fund', 'Financial Stability', 'Household Spending', 'Financial Independence', 'Financial Management', 'Resilience to Financial Shock', 'Discretionary Expenses', 'Income Expenditure Imbalance', 'Healthcare Costs', 'Financial Anxiety', 'Retirement Planning', 'Consumer Demand', 'Savings Rate Decline', 'Financial Flexibility', 'Discretionary Spending', 'Financial Goals', 'Emergency Funds', 'Investment Planning', 'Living Costs', 'Socioeconomic Stratum', 'Quality of Life', 'Financial Constraints', 'Affluent Households', 'Lower-Income Households', 'Mutual Funds', 'Socioeconomic Diversity', 'Wealth Creation', 'Digital Transactions', 'Accessibility', 'Economic Diversity', 'Empowerment Tools', 'Financial Security', 'Wealth Accumulation', 'Investment Strategy', 'Economic Resilience', 'Investor Centric Approach', 'Affordability', 'Transparency', 'Long-term Wealth Building', 'Mutual Fund Investment', 'Investor Journey', 'Financial Resilience', 'Onboarding Process', 'Personalized Investment', 'Cultural Economic Nuance', 'Financial Mindset', 'Community Wisdom', 'Digital Platform Access', 'User-Centric Design', 'Investment Mindset', 'Digital Interface', 'Simplicity in Communication', 'Inclusiveness in Finance', 'Cognitive Overload', 'Linguistic Diversity', 'Accessibility in Finance', 'Last-Mile Connectivity', 'Behavioural Mindset Change', 'Simplified Language', 'Investment Products', 'Offline Integration', 'Personalized Experience', 'User Journey', 'Behavioral Nudges', 'Educational Content', 'Collaborative Support', 'One-Click Assistance', 'Feedback Loops', 'User-Centric Platform', 'Regional Language Support', 'Intuitive Design', 'Financial Accessibility', 'User Experience', 'Cultural Narrative', 'System Interoperability', 'Regulatory Guidelines', 'Tailored Solutions', 'Holistic Ecosystem', 'Thematic Funds', 'Emotional Intelligence', 'Cultural Preservation', 'Financial Growth', 'Community Investment', 'Local Projects', 'Investment Vehicle', 'Crowdfunding Model', 'Systematic Withdrawal Plan', 'Social Impact Bonds', 'Sustainable Infrastructure', 'Technology-Driven Investment', 'Digital Asset Platform', 'Wealth-Building Opportunity', 'Cultural Transformation', 'Local Language', 'Mutual Fund Strategy', 'Digital Connectivity', 'Ethnographic Research', 'Regional Dietary Practices', 'User-Friendly Experience', 'Inclusive Ecosystem', 'Stakeholder Collaboration', 'Visually Impaired Support', 'Gig Worker Financial Products', 'Financial Literacy Programs', 'Inclusive Financial Design', 'Community Outreach', 'Tax Compliance Guidance', 'Audio-Visual Communication', 'Market Research Insights', 'Pilot Program Implementation', 'Inclusive Product Structure', 'Visua ...
# Row 9: Financial health: Transcending from access to impact → Category: Economy and Growth, Niche: Financial Inclusion
#  59%|█████▉    | 10/17 [05:18<04:26, 38.02s/it]
# Row 9: Key Themes: ['Financial Inclusion', 'Economic Growth', 'Digital Finance', 'Customer Retention', 'Data-Driven Solutions', 'Financial Health', 'Digital Infrastructure', 'Debt Management', 'Access Metrics', 'Financial Wellbeing']
# Row 9: Recurring Topics: ['Pradhan Mantri Jandhan Yojana', 'Aadhaar Biometric Identification', 'Financial Health', 'Retail Investor', 'Access to Financial Services', 'Impactful Financial Inclusion', 'Income Stability', 'Low-Income Households', 'Financial Service Providers', 'Behavioral Insights', 'Market-Linked Investments', 'Policy Initiatives', 'Income Volatility', 'Risk Management', 'Data-Driven Solutions', 'Customer Retention', 'Technological Innovation', 'Financial Awareness', 'Access to Finance', 'Investment', 'Credit Score', 'Usage of Financial Products', 'Impact Measurement', 'Financial Health Survey', 'Government Insurance Schemes', 'Financial Wellbeing', 'Financial Inclusion', 'Access Metrics', 'Usage Metrics', 'PMJDY Accounts', 'Financial Products', 'Diagnostic Tools', 'Household Financial Health', 'Sociodemographic Features', 'Investment and Savings', 'Borrowing Resilience', 'Informal Money Management', 'Digital Infrastructure', 'Household Financial Behaviour', 'Investment Products', 'Market-Linked Instruments', 'Equity Mutual Funds', 'Credit Penetration', 'Alternative Investments', 'Insurance Products', 'Pension Products', 'Digitalisation', 'Consumer Demand', 'Retail Participation', 'Financial Stability', 'Household Cashflow', 'Wealth Management Services', 'Financial Service Provider', 'Customer Insight', 'Formal Finance Transition', 'Consumer Spending', 'Investment Solutions', 'Market Insight', 'Hybrid Products', 'Long-term Capital Availability', 'Cross-industry Collaboration', 'Bharat Segment', 'Product Feedback', 'Risk Appetite', 'Financial Resilience', 'Infrastructure Investment', 'Personal Debt', 'Customer Segmentation', 'Investment Strategy', 'Thematic ESG Funds', 'Hybrid Insurance Products', 'Dynamic Risk-Based Lending', 'Digital-First Plans', 'Market Penetration', 'Hyper-Personalization', 'Loan Products', 'Credit Approval Challenges', 'First-Time Investors', 'Agri Space Hedging', 'Customer Education', 'Savings Solutions', 'Microloans', 'Credit Accessibility', 'Strategic Partnerships', 'Personalized Financial Services', 'Behavioral Finance', 'Technology Integration', 'Automated Savings', 'Unsecured Loans', 'E-commerce Collaboration', 'Data Analytics', 'Hyperpersonalization', 'Customer Persona Segmentation', 'Financial Decision Making', 'Spending Pattern Analysis', 'Predictive Financial Health Score', 'Personalized Financial Advisory', 'Socioeconomic Factors', 'Machine Learning', 'Financial Institution Insights', 'Dynamic Financial Solutions', 'Customer Engagement', 'Product Development', 'Market Strategy', 'Financial Empowerment', 'Economic Growth', 'Sustainable Development', 'Financial Service Customization', 'socio economic growth', 'policy making process', 'knowledge based economy', 'inclusive development', 'healthcare education', 'empowerment initiatives', 'civil society', 'financial services', 'public good', 'professional advice', 'network firm', 'quality assurance', 'tax service', 'Financial Service Sector', 'PwC India', 'Partner Leadership', 'Financial Service Technology', 'Advisory Services', 'Research Contributors']
# Row 10: Towards a climate-resilient future: Strategies for the Andaman and Nicobar Islands → Category: ESG, Niche: Climate Adaptation Strategies
#  65%|██████▍   | 11/17 [06:15<04:22, 43.71s/it]
# Row 10: Key Themes: ['Climate Resilience', 'Sustainable Development', 'Financing Solutions', 'Ecological Sensitivity', 'Climate Change', 'Land Use', 'Green Finance', 'Economic Development', 'Biodiversity Preservation', 'Ecosystem Protection', 'Ecosystem Management', 'Land Use Change', 'Agricultural Practices', 'Biodiversity Loss', 'Sustainable Management', 'Impact on Small Islands', 'Adaptation Strategies', 'Coastal Vulnerability', 'Environmental Impact', 'Biodiversity']
# Row 10: Recurring Topics: ['Andaman Nicobar Islands', 'Climate Change Impact', 'Comprehensive Action Plan', 'Green Finance Options', 'Vulnerability Assessment', 'Carbon Credit', 'Climate Change', 'Vulnerability Index', 'Clean Cookstove', 'Mangrove Restoration', 'Climate Action Plan', 'Carbon Market', 'Renewable Energy', 'Agricultural Activity', 'Ecological Impact', 'Infrastructure Projects', 'Natural Resources', 'Ecological Sensitivity', 'Climate Resilience', 'Geopolitical Importance', 'Greenhouse Gas Mitigation', 'Adaptation Options', 'Socioeconomic Inequity', 'Stakeholder Consultation', 'Climate-Smart Agriculture', 'Urbanization', 'Extreme Weather Events', 'Land Cover Patterns', 'Evergreen Semi-Evergreen Woodland', 'Kharif Crop', 'Annual Crop', 'Degraded Woodland', 'Water Bodies', 'Mangrove Area', 'Built-Up Area', 'Mangrove Loss', 'Forest Cover Decline', 'Coastal Protection', 'Human Activities', 'Natural Disasters', 'Ecological Consequences', 'Temperature Increase', 'Rainfall Variability', 'Sea Level Rise', 'Monsoon Patterns', 'Vulnerable Populations', 'Cyclone Risk', 'Coastal Erosion', 'Rainfall Changes', 'Nature-based sectors', 'Agriculture impact', 'Water resource availability', 'Marine ecosystems', 'Community resilience', 'Land use change', 'Coastal Marine Ecosystems', 'Agricultural Productivity', 'Adaptation Strategies', 'Biodiversity Conservation', 'Soil Degradation', 'Erosion Increase', 'Nutrient Leach', 'Salinity Distribution', 'Pest Diseases', 'Sustainable Development', 'Climate Vulnerability Index', 'Socioeconomic Vulnerability', 'Climate Resilience Strategy', 'Mangrove Degradation', 'Extreme Events', 'Adaptation Measures', 'Household Structure', 'Access to Basic Services', 'Human Development Index', 'Socioeconomic Status', 'Gender and Age Factors', 'Income and Poverty', 'Housing Quality', 'Food Insecurity', 'Disability and Illiteracy', 'Vulnerability Score', 'Biophysical Vulnerability', 'Economic Instability', 'Access to Amenities', 'Natural Systems', 'Kutcha Houses', 'Biodiversity Assessment', 'Adaptation Intervention', 'biodiversity loss', 'climate variability', 'cyclone exposure', 'agriculture tourism', 'urbanisation', 'habitat fragmentation', 'climate adaptation', 'composite vulnerability index', 'ecosystem restoration', 'resource allocation', 'subdistricts comparison', 'socioeconomic factors', 'natural disaster impact', 'pilot site prioritization', 'vulnerability', 'socioeconomic profile', 'subdistricts', 'population demographics', 'illiteracy rates', 'income brackets', 'household income', 'targeted intervention', 'economic participation', 'caste population', 'manual casual labour', 'cooking fuel', 'drinking water source', 'toilet facility', 'electricity access', 'road infrastructure', 'public primary school', 'vulnerability categories', 'Village School Availability', 'Healthcare Access', 'Public Health Centre', 'Mitigation Strategies', 'Agroforestry', 'Soil Health', 'Carbon Sequestration', 'Livelihood Enhancement', 'Clean Cookstoves', 'Mangrove Conservation', 'Food Security', 'Economic Stability', 'Job Creation', 'Biochar Production', 'Climate Change Mitigation', 'Coconut Husk', 'Economic Development', 'Sustainable Practices', 'Green Finance', 'Indoor Air Quality', 'Energy Security', 'Biodiversity Preservation', 'Waste Management', 'Livelihood Improvement', 'Environmental Benefits', 'Emission Reduction', 'Environmental Projects', 'Financial Resources', 'Investment Mechanisms', 'Pollution Prevention', 'Circular Economy', 'Feasibility Assessment', 'Impact Investment', 'Accessibility of Financing', 'Afforestation', 'Reforestation', 'Sequestration', 'Cookstove Technology', 'Biochar Utilization', 'Project Design', 'Applicability Condition', 'Community Assessment', 'Energy Efficiency', 'Agroforestry Assessment', 'Carbon Credit Revenue', 'Sustainable Management', 'Decentralized Thermal Energy', 'carbon credits', 'firewood as fuel', 'household energy access', 'diesel replacement', 'annual revenue estimation', 'grid- ...
# Row 11: The retail reinvention paradigm → Category: Transformation, Niche: Retail Innovation
#  71%|███████   | 12/17 [06:56<03:34, 43.00s/it]
# Row 11: Key Themes: ['Retail Reinvention', 'Ecommerce Growth', 'Consumer Engagement', 'Consumer Behavior', 'Omnichannel Retail', 'Digital Technology', 'Offline Shopping', 'Consumer Experience', 'Technology Integration', 'Consumer Data', 'Qcommerce Impact', 'Qcommerce', 'Retail Adaptation']
# Row 11: Recurring Topics: ['Brick-and-Mortar Retail', 'Tier 2 and 3 Cities', 'Digital Commerce', 'Consumer Utility', 'Hybrid Model', 'Retail Strategy', 'Omnichannel Shopping', 'Quick Commerce', 'Customer Expectations', 'Market Trends', 'Digital Wave', 'Ecommerce Integration', 'Traditional Retail', 'Shopping Experience', 'Jevons Paradox', 'Consumer Preferences', 'Market Survey', 'Online Shopping', 'Offline Shopping', 'Hybrid Approach', 'Retail Ecosystem', 'In-store Experience', 'Online Shopping Preference', 'Retail Personalization', 'Consumer Insights', 'Immersive Retail', 'Digital Tools', 'Retailer Challenges', 'Customer Preferences', 'Sales Decline', 'Inventory Management', 'Delivery Costs', 'Urban Convenience', 'Quick Delivery', 'Consumer Preference', 'Dark Stores', 'Convenience', 'Product Variety', 'Instant Gratification', 'Qcommerce', 'Consumer Expectations', 'Impulse Purchases', 'Ecommerce Growth', 'Customer Experience', 'Tier 1 Cities', 'Retail Reinvention', 'Last-Minute Purchases', 'Digital Shift', 'Customer Service', 'Online Shopping Threat', 'Retailer Perception', 'Ecommerce Opportunity', 'Sales Dip', 'Traditional Retail Impact', 'Digital Commerce Growth', 'Customer Service Improvement', 'Product Awareness', 'Deep Discount Strategies', 'Omnichannel Influence', 'Retail Reinvention Paradigm', 'Home Delivery', 'Customer Relationship Management', 'Traditional Retailer', 'Kirana Store', 'Market Engagement Strategy', 'Financial Support', 'Customer Engagement Activities', 'Ecommerce Competition', 'Dark Store', 'Technology Access', 'Operational Cost', 'Personalized Customer Service', 'Promotional Activities', 'Retailer Awareness', 'Data-Driven Analytics', 'Competitive Pricing', 'Consumer Experience', 'Return Policies', 'Aftersales Service', 'Payment Options', 'Product Availability', 'Stock Levels', 'Credit Facilities', 'E-commerce Competition', 'Delivery Logistics', 'Government Support', 'Government Intervention', 'Omnichannel Experience', 'Tactile Engagement', 'Influencer Culture', 'Seamless Shopping Journey', 'Hybrid Retail Model', 'Hyperlocal Fulfillment', 'Qcommerce Challenges', 'Hyperlocal Delivery', 'Digital Transformation', 'Operational Friction', 'Technology Integration', 'Ecommerce Platform', 'Digital Integration', 'Retail Landscape', 'Supply Chain Efficiency', 'Metro City Retailers', 'Tier 2 Tier 3 Cities', 'Customer Engagement', 'Omnichannel Strategy', 'Business Capability', 'Cost Reduction', 'Competitive Advantage', 'Consumer Trends', 'Online Marketplace', 'Traditional Retailers', 'Consumer Engagement', 'Digital Experience', 'Product Offering', 'Ecommerce Tools', 'Market Opportunities', 'Brand Advocacy', 'Data Utilization', 'Omnichannel Retail Strategy', 'Dark Store Concept', 'Qcommerce Demand', 'Consumer Behavior', 'Brand Relevance', 'Strategic Choice', 'Consumer Cohort', 'Retail Channel', 'Product Discoverability', 'Value for Money', 'Social Value', 'Purchase Decision', 'Assortment Variety', 'Price Sensitivity', 'Consumer Cohorts', 'Income Groups', 'Online Channel Utility', 'Offline Channel Utility', 'Consumption Patterns', 'Premium Chocolate Brand', 'Socioeconomic Classification', 'Market Research', 'Consumer Survey', 'Online Shopping Behavior', 'Tier 2 Cities', 'Retailer Insights', 'Kirana Club', 'Digital Community', 'Market Shift', 'Consumer Classification', 'Operational Sales', 'Face-to-Face Interviews', 'Gender Breakdown', 'Occupation Classification', 'Collaboration with FMCG Brands', 'Professional Advice', 'Liability Disclaimer', 'Publication Responsibility', 'Decision Making', 'Content Accuracy']
# Row 12: PwC India's Financial Services (FS) Risk Symposium: Ministry of Finance keynote session - February 2025 → Category: Risk Regulation, Niche: Financial Risk Management
#  76%|███████▋  | 13/17 [07:02<02:07, 31.83s/it]
# Row 12: Key Themes: ['Cybersecurity', 'Regulatory Compliance', 'Risk Management']
# Row 12: Recurring Topics: ['Financial Services', 'KYC Compliance', 'AML Challenges', 'Geopolitical Risks', 'Data Protection', 'Crypto Vulnerabilities', 'Cybersecurity Measures', 'Incident Response System', 'Regulatory Compliance', 'National Risk Assessment', 'Geopolitical Risk', 'Client Due Diligence', 'Risk Management Strategy', 'Private Sector Involvement', 'Employee Psychology', 'Reputational Damage']
# Row 13: How India spends: A deep dive into consumer spending behaviour → Category: Economy and Growth, Niche: Consumer Behavior
#  82%|████████▏ | 14/17 [08:16<02:13, 44.46s/it]
# Row 13: Key Themes: ['Consumer Spending', 'Economic Growth', 'Digital Infrastructure', 'Digital Payments', 'Financial Institutions', 'Consumer Behavior', 'Ecommerce Growth', 'Fintech Solutions', 'Spending Patterns', 'Financial Inclusion', 'Consumer Engagement', 'Financial Services', 'Investment Trends', 'Digital Access', 'Financial Analysis', 'Data Privacy', 'Income Segmentation', 'Economic Factors', 'Digital Commerce', 'Investment Behavior', 'Income Distribution', 'Loan Repayment', 'Income Levels', 'Income Disparity', 'E-commerce Growth', 'Income Bracket', 'Fashion Purchases', 'City Tier']
# Row 13: Recurring Topics: ["India's Middle Class", 'Transactional Data', 'Consumer Behavior', 'Investment Patterns', 'Indian Consumption', 'Financial Management', 'Credit Products', 'Market Growth', 'Indian Consumer Market', 'Spending Categories', 'Payment Modes', 'Government Regulation', 'Emotional Spending', 'UPI Transactions', 'Obligatory Expenditures', 'Discretionary Spending', 'Income Levels', 'Medical Expenses', 'Loan Products', 'Entry-Level Earners', 'Customer Loyalty', 'Payment Solutions', 'Healthcare Partnerships', 'Cashback Programs', 'Digital Wallet Integration', 'Household Consumption', 'Smartphone Access', 'Financial Inclusion', 'Urbanization', 'Debt Accumulation', 'Income Level', 'Geographic Location', 'Payment Instruments', 'Transaction Categories', 'Salary Buckets', 'Employment Rate', 'Inflation Impact', 'Basic Needs', 'Government Policy', 'Brand Loyalty', 'Social Factors', 'E-commerce Growth', 'Obligatory Expenses', 'Necessity Expenses', 'Income Bracket', 'Financial Literacy', 'Investment Options', 'Obligatory Expenditure', 'EMI Payments', 'Personal Loans', 'Housing Loans', 'Income Brackets', 'City Tiers', 'High Income Earners', 'Loan EMIs', 'Metro Cities', 'Informal Credit Sources', 'Tiered Cities', 'Lifestyle Purchases', 'Salary Bracket', 'Metro vs. Tier Cities', 'General Shopping', 'Fashion Spending', 'Personal Care', 'Online Shopping', 'Average Amount Spent', 'High-Income Earners', 'Fashion Shopping Frequency', 'Personal Care Purchases', 'Transaction Count', 'Personal Care Spending', 'Transaction Frequency', 'Tier City Spending', 'Consumer Behavior Analysis', 'Mid-Level Professionals', 'Ecommerce Platform', 'Online Gaming', 'Mobile Game', 'Metro City', 'Consumer Spending Behavior', 'Smartphone Penetration', 'Online Gaming Spending', 'Tier City Analysis', 'Monthly Transaction Average', 'Food Delivery Trends', 'Income Bracket Expenditure', 'Urban Lifestyle Impact', 'Esports Market Growth', 'Recreational Activity Popularity', 'Fantasy Game Popularity', 'Consumer Spending Behaviour', 'Food-Related Expenses', 'Income Level Impact', 'Entertainment Spending', 'Mobile Phone Entertainment', 'Premiumisation Trends', 'OTT Platform Expenditure', 'Tier 1 vs Tier 2 Cities', 'Streaming Services', 'Digital Medium Accessibility', 'Regional Language Content', 'Liquor Spirit Consumption', 'Disposable Income', 'Average Amount Spend', 'Liquor Spirits-Related Expense', 'Number of Transactions', 'City Tier', 'High-Income Earner', 'Midlevel Earner', 'Entry-Level Earner', 'Health-Related Risks', 'Alcohol Consumption Habits', 'Travel Preferences', 'Transportation Modes', 'Air Travel', 'Train Travel', 'Spending Behavior', 'Liquor Consumption', 'Expenditure Analysis', 'Public Transport', 'Low-Income Group', 'Travel-Related Expenses', 'Consumer Spending', 'Airport Infrastructure', 'Travel Categories', 'Air Travel Preferences', 'Travel Expenses', 'Utility Expenses', 'Household Expenditure', 'LPG Consumption', 'Power Consumption', 'Discretionary Expenses', 'Travel Aggregators', 'Essential Services', 'Urbanisation Impact', 'Grocery Spending', 'Household Items', 'Retail Landscape', 'Household Expense', 'Tier 1 City', 'Tier 2 City', 'Tier 3 City', 'Average Spending', 'Rental Lifestyle', 'Maintenance Costs', 'Quality of Items', 'Payment Methods', 'Competitive Pricing', 'Ecommerce Adoption', 'Grocery Quality', 'Online Grocery Shopping', 'House Rent Expenditure', 'Urban Relocation', 'Urbanization Impact', 'Health Insurance', 'Tiered City Analysis', 'Living Standards', 'Healthcare Expenditure', 'City Tier Differences', 'Health Insurance Penetration', 'Preventive Healthcare Measures', 'Fuel Consumption', 'Transportation Costs', 'Education Expenses', 'Telecommunication Services', 'Public Transport Reliance', 'Investment Behavior', 'Mutual Funds', 'Financial Planning', 'Digital Investment Platforms', 'Demat Accounts', 'Economic Climate', 'Asset Management', 'Stock Market Participation', 'Financialization of Savings', 'Digital Platforms', 'Salary  ...
# Row 14: The future of quality in manufacturing → Category: Transformation, Niche: Quality Management Systems
#  88%|████████▊ | 15/17 [08:29<01:10, 35.04s/it]
# Row 14: Key Themes: ['Quality Evolution', 'Manufacturing Innovation', 'Technology Integration', 'Quality Management', 'Sustainability', 'Employee Engagement']
# Row 14: Recurring Topics: ['Quality 50', 'Consumer Expectations', 'Data-Driven Approach', 'Stakeholder Needs', 'Technological Innovation', 'Human Insight', 'Data Management', 'Collaboration', 'Continuous Learning', 'Product Quality', 'Market Adaptability', 'Customer Satisfaction', 'Sustainability Consideration', 'Real-time Quality Monitoring', 'Predictive Quality Analytics', 'Service Quality', 'Customer Experience', 'Data Quality', 'Operational Success', 'Environmental Impact', 'Data Quality Assurance', 'Blockchain Technology', 'Regulatory Compliance', 'Quality Control', 'Employee Wellbeing', 'Automation in Compliance', 'Supply Chain Management', 'Digital Skills', 'Integrated Systems', 'Quality Management System', 'Change Management', 'Data Infrastructure', 'Employee Buy-in', 'Process Integration', 'Technology Selection', 'Operational Efficiency', 'Stakeholder Collaboration', 'Training and Support', 'Security Assessment', 'Quality Management', 'Competitive Edge', 'Professional Advice', 'Innovation', 'Sustainable Quality', 'PricewaterhouseCoopers', 'Advisory Services']
# Row 15: Powering automation with agents → Category: Technology, Niche: Robotic Process Automation
#  94%|█████████▍| 16/17 [08:45<00:29, 29.42s/it]
# Row 15: Key Themes: ['Automation', 'Artificial Intelligence', 'Business Transformation', 'Intelligent Automation', 'Multi-Agent Systems', 'User Interaction', 'AI Collaboration', 'Human Augmentation']
# Row 15: Recurring Topics: ['Power Automation Agent', 'Intelligent Automation', 'AI Technology', 'Productivity Efficiency', 'Generative AI', 'Decision Making', 'Automation Framework', 'Goal-Oriented Agents', 'Workflow Orchestration', 'User Feedback', 'Self-Improvement', 'Agent Autonomy', 'Human Intervention', 'Emotional Intelligence', 'Context Awareness', 'Task Execution', 'Agentic Workflow', 'Automation', 'AI Integration', 'Process Improvement', 'Ethical Guidelines', 'Human Feedback', 'Self-learning Capability', 'Performance Analysis', 'Workflow Management', 'Data Management', 'Continuous Monitoring', 'Proactive Action', 'Collaboration', 'Efficiency and Productivity', 'Agent Orchestration', 'Task Automation', 'Invoice Processing', 'Expense Reconciliation', 'Cash Flow Management', 'Demand Forecasting', 'Inventory Visibility', 'Supplier Onboarding', 'Lead Generation', 'Brand Monitoring', 'Sentiment Analysis', 'Automation Agent', 'Job Description Creation', 'Candidate Screening', 'Background Verification', 'Employee Engagement', 'Disaster Recovery', 'Asset Management', 'SEO Optimization', 'Customer Feedback', 'Talent Acquisition Process', 'Recruiter Productivity', 'Candidate Profile Screening', 'Resume Screening', 'Interview Scheduling', 'Performance Management', 'Compliance Management', 'Mass Recruitment Challenges', 'Keyword Search Optimization', 'Feedback Mechanism', 'HR Administration Automation', 'Self-service Payroll Management', 'AI Agent Governance', 'Ethical AI Implementation', 'Data Privacy Safeguards', 'Human-AI Workforce Integration', 'Regulatory Compliance', 'Training and Development', 'Transparency and Fairness', 'Performance Measurement', 'Innovation and Cost Efficiency', 'Governance Model', 'Organisational Risk', 'Societal Risk', 'Responsible AI Framework', 'Business Transformation', 'Customer Experience', 'Agentic Automation', 'Innovation', 'Quality Assurance', 'Professional Advice']
# Row 16: Deals at a glance: Annual review 2024 → Category: Economy and Growth, Niche: Market Trends
# 100%|██████████| 17/17 [09:04<00:00, 32.05s/it]
# Row 16: Key Themes: ['Economic Growth', 'Investment Trends', 'Mergers and Acquisitions', 'Domestic Transactions', 'Market Growth', 'Market Outlook']
# Row 16: Recurring Topics: ['Deal Volume', 'Private Equity Investment', "India's GDP Growth", 'Market Consolidation', 'Regulatory Amendments', 'Deal Value', 'Domestic Deals', 'Technology Sector', 'Healthcare Sector', 'Private Equity', 'large deals', 'renewable energy', 'joint ventures', 'domestic mergers', 'IPO activity', 'capital investment', 'Initial Public Offering', 'Mainboard IPO', 'SME IPO', 'Investment Growth', 'Private Credit', 'Real Estate Sector', 'Market Volatility', 'Credit Investment', 'Deal Structure', 'Global Investment Climate', 'Insolvency Framework', 'Corporate Insolvency Resolution Process', 'National Company Law Tribunal', 'Insolvency Bankruptcy Board of India', 'Voluntary Liquidation', 'Operational Creditor', 'Group Insolvency', 'Cross-Border Insolvency', 'Digital Personal Data Protection', 'NCLT Capacity', 'Infrastructure Improvement', 'Appointment of Tribunal Members', 'Mediation in Insolvency', 'Indian Economic Structure', 'IBC Improvement', 'Bankruptcy Procedure', 'Government Expenditure', 'Private Consumption', 'Gross Value Added', 'Manufacturing Growth', 'Export and Import', 'Central Government Capex', 'Service Sector Growth', 'Economic Snapshot', 'Industrial Production Growth', 'Manufacturing PMI', 'Service PMI', 'Passenger Vehicle Sales', 'Two-Wheeler Sales', 'Consumer Price Index', 'Retail Sales', 'Mining Production', 'Electricity Production', 'FMCG Growth', 'Unemployment Rate', 'Market Sentiment', 'Inventory Levels', 'Capital Goods', 'Consumer Durables', 'Consumer Non-Durables', 'Inflation Rate', 'Domestic Traffic Growth', 'Corporate Deal Activity', 'Megadeals', 'Economic Uncertainty', 'Artificial Intelligence', 'Corporate Divestiture', 'Investment Strategies', 'Energy Sector', 'E-commerce', 'Battery Manufacturing', 'Geopolitical Unpredictability', 'Central Bank Interest Rates', 'Inflation Impact', 'Market Valuation', 'Investor Behavior', 'Economic Recovery', 'Professional Advice', 'PWC Services']
# C:\Users\HP\AppData\Local\Temp\ipykernel_8668\2777372178.py:273: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['date'] = pd.to_datetime(df['date'], errors='coerce', infer_datetime_format=True).dt.strftime('%m/%d/%y')
# Processing complete. Final results saved.

# %%
date_mapping = df2.set_index("title")["date"]
df.loc[df["title"].isin(date_mapping.index), "date"] = df["title"].map(date_mapping)

df.head(16)
# Out:
#            source                                           url_link  \
# 0   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/aau-ac...
# 1   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/food-a...
# 2   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/financ...
# 3   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/kpmg-g...
# 4   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/kpmg-g...
# 5   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/kpmg-g...
# 6   KPMG Insights  https://kpmg.com/in/en/insights/2025/02/kpmg-g...
# 7    PWC Insights                                                NaN
# 8    PWC Insights                                                NaN
# 9    PWC Insights                                                NaN
# 10   PWC Insights                                                NaN
# 11   PWC Insights                                                NaN
# 12   PWC Insights                                                NaN
# 13   PWC Insights                                                NaN
# 14   PWC Insights                                                NaN
# 15   PWC Insights                                                NaN
#
#                                                 title  \
# 0                       Issue no. 103 | February 2025
# 1              Food and Nutritional Security in India
# 2                            Financial Crime Bulletin
# 3   KPMG global tech report – industrial manufactu...
# 4        KPMG global tech report: Technology insights
# 5            KPMG global tech report: energy insights
# 6                        KPMG global tech report 2024
# 7   Quality measures and standards for transitioni...
# 8       The mutual funds route to Viksit Bharat @2047
# 9   Financial health: Transcending from access to ...
# 10  Towards a climate-resilient future: Strategies...
# 11                    The retail reinvention paradigm
# 12  PwC India's Financial Services (FS) Risk Sympo...
# 13  How India spends: A deep dive into consumer sp...
# 14             The future of quality in manufacturing
# 15                    Powering automation with agents
#
#                                           description      date  \
# 0   This edition of AAU covers relevant financial ...  02/28/25
# 1   Solutions for achieving zero hunger and ensuri...  02/20/25
# 2   Dive deep into the financial crime avenues and...  02/10/25
# 3   Interoperability, hybrid models and AI innovat...  02/07/25
# 4   Tech: A bold sector that innovates while leadi...  02/07/25
# 5   Empower your digital transformation with data-...  02/07/25
# 6   In the race to keep up with rapid tech innovat...  02/06/25
# 7     A roadmap to facilitate the transition to VBHC.  07/03/25
# 8   A comprehensive roadmap for the evolution of t...  05/03/25
# 9   Explore India’s financial inclusion journey an...  04/03/25
# 10  Explore the comprehensive climate-resilient ac...  04/03/25
# 11                     How brands could up their game  27/02/25
# 12  The forum shed light on the evolving complexit...  25/02/25
# 13  Powered by the robust growth of the Indian eco...  24/02/25
# 14  Explore the evolution of quality, the growing ...  21/02/25
# 15  Explore the world of APA, highlighting its app...  18/02/25
#
#                                               content  \
# 0   Ind AS 103, Business Combination provides guid...
# 1   Food security has been a critical aspect of In...
# 2   Financial crimes have become an ever-evolving ...
# 3   In the rapidly evolving landscape of industria...
# 4   The digital transformation journey is an impor...
# 5   The energy industry is at a pivotal moment of ...
# 6   As tech innovation opens endless potential, te...
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
#
#                                              pdf_link  \
# 0   https://kpmg.com/content/dam/kpmgsites/in/pdf/...
# 1   https://kpmg.com/content/dam/kpmgsites/in/pdf/...
# 2                                                None
# 3   https://kpmg.com/content/dam/kpmgsites/xx/pdf/...
# 4   https://kpmg.com/content/dam/kpmgsites/xx/pdf/...
# 5   https://assets.kpmg.com/content/dam/kpmgsites/...
# 6   https://assets.kpmg.com/content/dam/kpmgsites/...
# 7   https://www.pwc.in/ghost-templates/quality-mea...
# 8   https://www.pwc.in/ghost-templates/the-mutual-...
# 9   https://www.pwc.in/ghost-templates/financial-h...
# 10  https://www.pwc.in/ghost-templates/towards-a-c...
# 11  https://www.pwc.in/ghost-templates/retail-rein...
# 12  https://www.pwc.in/ghost-templates/pwc-indias-...
# 13  https://www.pwc.in/ghost-templates/india-spend...
# 14  https://www.pwc.in/ghost-templates/future-qual...
# 15  https://www.pwc.in/ghost-templates/powering-au...
#
#                                           pdf_content  \
# 0   February 2025\nkpmg.com/in\nAccounting and \nA...
# 1   Food and nutritional \nsecurity in India\nSolu...
# 2
# 3   KPMG global \ntech report 2024\nKPMG Internati...
# 4   KPMG global \ntech report 2024\nKPMG Internati...
# 5   KPMG global \ntech report 2024\nKPMG Internati...
# 6   KPMG global \ntech report 2024\nKPMG Internati...
# 7   Quality measures and standards \nMarch 2025\nf...
# 8   The mutual funds route \nto Viksit Bharat @204...
# 9   TM\nMarch 2025\nFinancial health: \nTranscendi...
# 10   \nTowards a climate-resilient \nfuture: Strat...
# 11  The retail reinvention \nparadigm\nHow brands ...
# 12  May 2024\n6th February 2025\nKey takeaways fro...
# 13  How India spends: \nA deep dive into consumer\...
# 14  The future of quality \nin manufacturing\n2   ...
# 15  Powering automation  \nwith agents\nPowering \...
#
#                                     concatenated_text  \
# 0   Ind AS 103, Business Combination provides guid...
# 1   Food security has been a critical aspect of In...
# 2   Financial crimes have become an ever-evolving ...
# 3   In the rapidly evolving landscape of industria...
# 4   The digital transformation journey is an impor...
# 5   The energy industry is at a pivotal moment of ...
# 6   As tech innovation opens endless potential, te...
# 7   Quality measures and standards for transitioni...
# 8   The mutual funds route to Viksit Bharat @2047 ...
# 9   Financial health: Transcending from access to ...
# 10  Towards a climate-resilient future: Strategies...
# 11  The retail reinvention paradigm How brands cou...
# 12  PwC India's Financial Services (FS) Risk Sympo...
# 13  How India spends: A deep dive into consumer sp...
# 14  The future of quality in manufacturing Explore...
# 15  Powering automation with agents Explore the wo...
#
#                                        tokenized_text  \
# 0   ind_as as_103 103_business business_combinatio...
# 1   food_security security_has has_been been_a a_c...
# 2   financial_crimes crimes_have have_become becom...
# 3   in_the the_rapidly rapidly_evolving evolving_l...
# 4   the_digital digital_transformation transformat...
# 5   the_energy energy_industry industry_is is_at a...
# 6   as_tech tech_innovation innovation_opens opens...
# 7   quality_measures measures_and and_standards st...
# 8   the_mutual mutual_funds funds_route route_to t...
# 9   financial_health health_transcending transcend...
# 10  towards_a a_climateresilient climateresilient_...
# 11  the_retail retail_reinvention reinvention_para...
# 12  pwc_indias indias_financial financial_services...
# 13  how_india india_spends spends_a a_deep deep_di...
# 14  the_future future_of of_quality quality_in in_...
# 15  powering_automation automation_with with_agent...
#
#                          normalized_concatenated_text            category  \
# 0   ind 103 business combination provide guidance ...  Economy and Growth
# 1   food security critical aspect indias public po...     India (Country)
# 2   financial crime become everevolving problem me...     Risk Regulation
# 3   rapidly evolve landscape industrial manufactur...          Technology
# 4   digital transformation journey important strat...          Technology
# 5   energy industry pivotal moment transformation ...   Energy Renewables
# 6   tech innovation open endless potential tech le...          Technology
# 7   quality measure standard transition valuebased...          Healthcare
# 8   mutual fund route viksit bharat 2047 comprehen...  Economy and Growth
# 9   financial health transcend access impact explo...  Economy and Growth
# 10  towards climateresilient future strategy andam...                 ESG
# 11  retail reinvention paradigm brand could game r...      Transformation
# 12  pwc indias financial service f risk symposium ...     Risk Regulation
# 13  india spend deep dive consumer spending behavi...  Economy and Growth
# 14  future quality manufacturing explore evolution...      Transformation
# 15  power automation agent explore world apa highl...          Technology
#
#                             niche  \
# 0                Inflation Trends
# 1             Agricultural Policy
# 2           Anti-Money Laundering
# 3                  Industrial IoT
# 4           Emerging Technologies
# 5    Sustainable Energy Solutions
# 6           Emerging Technologies
# 7                Value-Based Care
# 8           Investment Strategies
# 9             Financial Inclusion
# 10  Climate Adaptation Strategies
# 11              Retail Innovation
# 12      Financial Risk Management
# 13              Consumer Behavior
# 14     Quality Management Systems
# 15     Robotic Process Automation
#
#                                            key_themes  \
# 0   [Business Combination, Sustainability Disclosu...
# 1   [Food Security, Public Policy, Sustainable Agr...
# 2   [Financial Crime, Regulatory Initiatives, Risk...
# 3   [Digital Transformation, Operational Efficienc...
# 4   [Digital Transformation, Technology Strategy, ...
# 5   [Energy Transformation, Technological Innovati...
# 6   [Tech Innovation, Strategic Decision-Making, V...
# 7   [Value-Based Healthcare, Quality Measurement, ...
# 8   [Financial Inclusion, Investor Empowerment, Mu...
# 9   [Financial Inclusion, Economic Growth, Digital...
# 10  [Climate Resilience, Sustainable Development, ...
# 11  [Retail Reinvention, Ecommerce Growth, Consume...
# 12  [Cybersecurity, Regulatory Compliance, Risk Ma...
# 13  [Consumer Spending, Economic Growth, Digital I...
# 14  [Quality Evolution, Manufacturing Innovation, ...
# 15  [Automation, Artificial Intelligence, Business...
#
#                                      recurring_topics
# 0   [Acquisition Method, Measurement Period, Provi...
# 1   [Public Distribution System, Nutritional Progr...
# 2   [Anti-Money Laundering, Fraud Detection, Benef...
# 3   [Industrial Manufacturing, Data Strategy, Cybe...
# 4   [AI and ESG, Risk Management, Evidence-Based D...
# 5   [AI and Advanced Analytics, Evidence-Based Dec...
# 6   [Evidence-Based Decisions, Technology Leadersh...
# 7   [Patient Outcomes, Cost Efficiency, Healthcare...
# 8   [Democratization of Wealth, Financial Literacy...
# 9   [Pradhan Mantri Jandhan Yojana, Aadhaar Biomet...
# 10  [Andaman Nicobar Islands, Climate Change Impac...
# 11  [Brick-and-Mortar Retail, Tier 2 and 3 Cities,...
# 12  [Financial Services, KYC Compliance, AML Chall...
# 13  [India's Middle Class, Transactional Data, Con...
# 14  [Quality 50, Consumer Expectations, Data-Drive...
# 15  [Power Automation Agent, Intelligent Automatio...
